# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
from sklearn.manifold import TSNE
from gensim.models import Word2Vec
import multiprocessing
import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", level=logging.INFO)

cores = multiprocessing.cpu_count() # Count the number of cores in a computer
print(cores)
# Out:
# 8

# %% [markdown]
# # Implementing the Node2Vec paradigm
# ## Algorithm
# - We are given an adjacency matrix -> this acts as a set of rules (vocabulary)
# - We are going to generate linear chains to be able to predict the context/neighborhood of a given node
# - So, using the adjacency matrix, we generate many random walks of a fixed length.
# - The random walks will become our dataset to feed and train the `SkipGram` model.

# %%
class Node2Vec():
        def __init__(
                        self, 
                        graph : "list[list[int]]", 
                        window_size : int, 
                        embedding_size : int, 
                        walks_per_vertex : int, 
                        walk_length : int,
                        p : float,
                        q : float
                ) -> None:
                """
                Initialize the DeepWalk model. This directly from the paper https://arxiv.org/pdf/1403.6652.pdf.

                Parameters
                ----------
                graph : list[list[int]]
                        The adjacency list to be embedded. This is a list of lists, where each list is a vertex and its neighbors.
                window_size : int
                        The window size for the skipgram model.
                embedding_size : int
                        The size of the embedding. The final output matrix will be of size |V| x embedding_size.
                walks_per_vertex : int
                        The number of walks to perform per vertex.
                walk_length : int
                        The length of each walk.
                p : float
                        The return parameter.
                q : float
                        The in-out parameter.

                Methods
                -------
                generate_n_walks()
                        Generate n walks from the graph.
                train()
                        Train the model.
                update()
                        Feed model new walks.
                get_embeddings()
                        Return the embeddings.
                """

                # DeepWalk parameters
                self.g = graph
                self.w = window_size
                self.d = embedding_size
                self.gamma = walks_per_vertex
                self.epochs = self.gamma
                self.t = walk_length
                self.n = len(graph)
                self.p = p
                self.q = q

        def second_order_biased_random_walk(
                        self,
                        adj_mat : 'list[list[int]]', 
                        walk_len : 'int', 
                        start_node : 'int', 
                        return_parameter :'float', 
                        in_out_parameter : 'float'
                        ) -> np.array:
                """
                Return a walk based on a 2nd order Markov Chain like transition.

                Parameters
                ----------
                adj_mat : list[list[int]]
                        Adjacency matrix of the graph.
                walk_len : int
                        Length of the random walk.
                start_node : int
                        Starting node of the random walk.
                return_parameter : float
                        The value of the "p" parameter
                in_out_parameter : float
                        The value of the "q" parameter
                
                Returns
                -------
                np.array
                        List of nodes in the random walk.  
                
                """
                # Array to store the walk
                walk = [
                        start_node, # Extra node to help uniformly sample the second node
                        start_node  # The actual walk we will return is walk
                ]

                # Make an adjacency list to easily 
                # sample the neighbors of a node.
                adj_list = [] # list of [node, weight]
                for i in range(len(adj_mat)):
                        neighbors = np.where(adj_mat[i] > 0)[0]  # Get neighbor indices
                        weights = adj_mat[i, neighbors]  # Get corresponding edge weights
                        adj_list.append(list(zip(neighbors, weights)))

                # Keep walking for walk_len epochs
                for walk_step in range(walk_len):
                        # 1) Assign a value of 1 / in_out 
                        #    to all neighbours of walk[-1]
                        # 2) Overwrite the value of all 
                        #    neighbours of walk[-2] with 1 
                        # 3) Overwrite walk[-2] by 1
                        # 4) Multiply each element by the 
                        #    weight of the corresponding edge. 
                        # Feed it to np.random.choice

                        # Current and Parent node 
                        curr_node = walk[-1]
                        prev_node = walk[-2]

                        # Using the parent_node id get the neighbours and their weights
                        neighbors, weights = zip(*adj_list[curr_node])
                        prev_neighbors, prev_weights = zip(*adj_list[prev_node])

                        # Get boolean arrays to mark current neighbours as previous node's neighbours
                        is_prev_neighbor = np.isin(neighbors, prev_neighbors)
                        is_prev_node = np.isin(neighbors, np.array([prev_node]))

                        # print(is_prev_neighbor, is_prev_node)
                        
                        # Calculate probabilities based on the return and in-out parameters
                        probabilities = np.zeros(len(neighbors), dtype=np.float64)
                        
                        probabilities[is_prev_node] = 1.0 / return_parameter
                        probabilities[is_prev_neighbor] = 1.0
                        probabilities[~(is_prev_node | is_prev_neighbor)] = 1.0 / in_out_parameter

                        # Normalize the probabilities
                        # probabilities /= np.sum(probabilities)

                        # Multiply each element by the weight of the corresponding edge
                        weighted_probabilities = probabilities * weights
                        # weighted_probabilities = probabilities

                        # Choose the next node based on the probabilities
                        next_node = np.random.choice(neighbors, p=weighted_probabilities / np.sum(weighted_probabilities))

                        walk.append(next_node)


                return np.array(walk[1:])

        def generate_n_walks(self, num_iters : int) -> 'list[list[str]]':
                """
                Generate a list of num_iters random walks. These will be used to train the model

                Parameters
                ----------
                num_iters : int
                        Number of walks to generate.

                Returns
                -------
                np.ndarray
                        List of random walks.
                """

                # List to store the walks
                walks = []

                # For each vertex in the graph
                for vertex in range(self.n):
                        # Generate gamma walks of length t
                        for _ in range(self.gamma):
                                walks.append(self.second_order_biased_random_walk(self.g, self.t, vertex, self.p, self.q))

                walks = [[str(node) for node in walk] for walk in walks]

                return walks

        def train(self, epochs : int, lr : float) -> None:
                """
                Train the model.

                Parameters
                ----------
                epochs : int
                        Number of epochs to train the model for.
                lr : float
                        Learning rate for the optimizer.                
                """

                # Generate many walks
                walks = self.generate_n_walks(self.gamma)

                # Initialize the model
                self.model = Word2Vec(
                        walks,
                        negative= 10,
                        sg=1,
                        alpha=0.05,
                        epochs=self.epochs, 
                        vector_size=self.d,        # embedding dimension
                        window=self.w,             # context window size
                        min_count=0,
                        workers=cores-2
                )

        def get_embeddings(self) -> np.ndarray:
                """
                Return the embeddings.

                Returns
                -------
                np.ndarray
                        Embeddings.
                """
                return [self.model.wv[str(n)] for n in range(self.n)]
        
        def plot_embeddings(self, num_dimensions : int, gt_labels : 'list[str]') -> None:
                """
                Plot the embeddings.

                Parameters
                ----------
                num_dimensions : int
                        Number of dimensions to plot.
                gt_labels : list[str]
                        List of ground truth labels.
                """
                embeddings = np.array(self.get_embeddings())

                # dimensionality reduction to 2 dimensions using t-SNE for visualization
                embeddings = TSNE(n_components=2).fit_transform(embeddings)

                # Convert gt into numbers
                gt_labels = np.array(gt_labels)

                # Iterate over all labels and assign them an integer
                for i, label in enumerate(np.unique(gt_labels)):
                        gt_labels[gt_labels == label] = i
                gt_labels = gt_labels.astype(int)

                # plot the embeddings
                plt.figure(figsize=(6,6))
                plt.scatter(embeddings[:,0], embeddings[:,1], c=gt_labels)

                # Plot node numbers
                for i in range(len(embeddings)):
                        plt.annotate(i , (embeddings[i,0], embeddings[i,1]))
                        
                plt.show()

# %%
def plot_graph ( G , node_colours):
    plt.figure(figsize=(8,8))
    # scale node size by degree
    node_sizes = [v * 20 for v in dict(G.degree()).values()]
    nx.draw_networkx(G, with_labels=False, node_color= node_colours, node_size= node_sizes,edgecolors="black", alpha=0.9)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Showing DeepWalk

# %%
G = nx.les_miserables_graph()
# draw a graph with light blue nodes outlined with black and grey edges (without labels)
plot_graph(G, "lightblue")

adjmat = nx.adjacency_matrix(G).todense()

# %%
# adjmat , window_size , embedding_size , walks_per_vertex , walk_length , p , q
n2v = Node2Vec(adjmat, 10, 128, 10, 80, 1, 1)

# %%
n2v.train(30, 0.05)
# Out:
# INFO - 2023-10-26 20:28:37,154: collecting all words and their counts
# INFO - 2023-10-26 20:28:37,154: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-10-26 20:28:37,159: collected 77 word types from a corpus of 62370 raw words and 770 sentences
# INFO - 2023-10-26 20:28:37,159: Creating a fresh vocabulary
# INFO - 2023-10-26 20:28:37,159: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-10-26T20:28:37.159842', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 20:28:37,160: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 62370 word corpus (100.00% of original 62370, drops 0)', 'datetime': '2023-10-26T20:28:37.160086', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 20:28:37,160: deleting the raw counts dictionary of 77 items
# INFO - 2023-10-26 20:28:37,160: sample=0.001 downsamples 51 most-common words
# INFO - 2023-10-26 20:28:37,160: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 18011.2221392198 word corpus (28.9%% of prior 62370)', 'datetime': '2023-10-26T20:28:37.160928', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 20:28:37,161: estimated required memory for 77 words and 128 dimensions: 117348 bytes
# INFO - 2023-10-26 20:28:37,161: resetting layer weights
# INFO - 2023-10-26 20:28:37,162: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-10-26T20:28:37.162375', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'build_vocab'}
# INFO - 2023-10-26 20:28:37,162: Word2Vec lifecycle event {'msg': 'training model with 6 workers on 77 vocabulary and 128 features, using sg=1 hs=0 sample=0.001 negative=10 window=10 shrink_windows=True', 'datetime': '2023-10-26T20:28:37.162565', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'train'}
# INFO - 2023-10-26 20:28:37,227: EPOCH 0: training on 62370 raw words (17935 effective words) took 0.1s, 282004 effective words/s
# INFO - 2023-10-26 20:28:37,291: EPOCH 1: training on 62370 raw words (17866 effective words) took 0.1s, 286260 effective words/s
# INFO - 2023-10-26 20:28:37,356: EPOCH 2: training on 62370 raw words (18094 effective words) took 0.1s, 284339 effective words/s
# INFO - 2023-10-26 20:28:37,421: EPOCH 3: training on 62370 raw words (18084 effective words) took 0.1s, 281574 effective words/s
# INFO - 2023-10-26 20:28:37,484: EPOCH 4: training on 62370 raw words (18060 effective words) took 0.1s, 297586 effective words/s
# INFO - 2023-10-26 20:28:37,547: EPOCH 5: training on 62370 raw words (18023 effective words) took 0.1s, 288209 effective words/s
# INFO - 2023-10-26 20:28:37,613: EPOCH 6: training on 62370 raw words (18161 effective words) took 0.1s, 283593 effective words/s
# INFO - 2023-10-26 20:28:37,679: EPOCH 7: training on 62370 raw words (18011 effective words) took 0.1s, 280298 effective words/s
# INFO - 2023-10-26 20:28:37,743: EPOCH 8: training on 62370 raw words (18125 effective words) took 0.1s, 288875 effective words/s
# INFO - 2023-10-26 20:28:37,809: EPOCH 9: training on 62370 raw words (18122 effective words) took 0.1s, 281761 effective words/s
# INFO - 2023-10-26 20:28:37,810: Word2Vec lifecycle event {'msg': 'training on 623700 raw words (180481 effective words) took 0.6s, 278842 effective words/s', 'datetime': '2023-10-26T20:28:37.809997', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'train'}
# INFO - 2023-10-26 20:28:37,810: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=128, alpha=0.05>', 'datetime': '2023-10-26T20:28:37.810225', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'created'}

# %%
# n2v.plot_embeddings(2, gt)

# %%
# # getting the embeddings from the model
embeddings = np.array(n2v.get_embeddings())

# from sknetwork.clustering import Louvain, get_modularity
# import scipy.sparse as sp
# from sknetwork.visualization import svg_graph, svg_bigraph

# louvain = Louvain()
# labels = louvain.fit_predict(adjmat)

# %%
# G = nx.karate_club_graph()
# nx.draw(G, with_labels=True, node_color=labels, cmap=plt.cm.rainbow)
# adjmat = nx.adjacency_matrix(G).todense()

# %%
# n2v.plot_embeddings(2, labels)

# %% [markdown]
# ## Showing Homophily

# %%
''' do k means clustering for different p and q values and assign 
colours to the nodes based on the cluster they belong to '''

# p = 1, q=0.5
n2v = Node2Vec(adjmat, 10, 128, 10, 80, 1, 0.5)
n2v.train(30, 0.05)
embeddings = np.array(n2v.get_embeddings())

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=0,n_init=10).fit(embeddings)
labels = kmeans.labels_

plot_graph(G, labels)
# Out:
# INFO - 2023-10-26 20:28:42,989: collecting all words and their counts
# INFO - 2023-10-26 20:28:42,990: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-10-26 20:28:42,994: collected 77 word types from a corpus of 62370 raw words and 770 sentences
# INFO - 2023-10-26 20:28:42,995: Creating a fresh vocabulary
# INFO - 2023-10-26 20:28:42,995: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-10-26T20:28:42.995405', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 20:28:42,995: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 62370 word corpus (100.00% of original 62370, drops 0)', 'datetime': '2023-10-26T20:28:42.995632', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 20:28:42,996: deleting the raw counts dictionary of 77 items
# INFO - 2023-10-26 20:28:42,996: sample=0.001 downsamples 56 most-common words
# INFO - 2023-10-26 20:28:42,996: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 18761.792462411726 word corpus (30.1%% of prior 62370)', 'datetime': '2023-10-26T20:28:42.996885', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 20:28:42,997: estimated required memory for 77 words and 128 dimensions: 117348 bytes
# INFO - 2023-10-26 20:28:42,998: resetting layer weights
# INFO - 2023-10-26 20:28:42,999: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-10-26T20:28:42.999028', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'build_vocab'}
# INFO - 2023-10-26 20:28:42,999: Word2Vec lifecycle event {'msg': 'training model with 6 workers on 77 vocabulary and 128 features, using sg=1 hs=0 sample=0.001 negative=10 window=10 shrink_windows=True', 'datetime': '2023-10-26T20:28:42.999439', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'train'}
# INFO - 2023-10-26 20:28:43,063: EPOCH 0: training on 62370 raw words (18585 effective words) took 0.1s, 294425 effective words/s
# INFO - 2023-10-26 20:28:43,129: EPOCH 1: training on 62370 raw words (18805 effective words) took 0.1s, 290665 effective words/s
# INFO - 2023-10-26 20:28:43,201: EPOCH 2: training on 62370 raw words (18919 effective words) took 0.1s, 275287 effective words/s
# INFO - 2023-10-26 20:28:43,270: EPOCH 3: training on 62370 raw words (18584 effective words) took 0.1s, 276617 effective words/s
# INFO - 2023-10-26 20:28:43,340: EPOCH 4: training on 62370 raw words (18817 effective words) took 0.1s, 275357 effective words/s
# INFO - 2023-10-26 20:28:43,409: EPOCH 5: training on 62370 raw words (18641 effective words) took 0.1s, 277984 effective words/s
# INFO - 2023-10-26 20:28:43,478: EPOCH 6: training on 62370 raw words (18730 effective words) took 0.1s, 276899 effective words/s
# INFO - 2023-10-26 20:28:43,547: EPOCH 7: training on 62370 raw words (18696 effective words) took 0.1s, 279489 effective words/s
# INFO - 2023-10-26 20:28:43,616: EPOCH 8: training on 62370 raw words (18745 effective words) took 0.1s, 279468 effective words/s
# INFO - 2023-10-26 20:28:43,687: EPOCH 9: training on 62370 raw words (18832 effective words) took 0.1s, 272994 effective words/s
# INFO - 2023-10-26 20:28:43,687: Word2Vec lifecycle event {'msg': 'training on 623700 raw words (187354 effective words) took 0.7s, 272319 effective words/s', 'datetime': '2023-10-26T20:28:43.687679', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'train'}
# INFO - 2023-10-26 20:28:43,687: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=128, alpha=0.05>', 'datetime': '2023-10-26T20:28:43.687939', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'created'}

# %% [markdown]
# ## Showing Structural Equivalence

# %%
# p = 1, q=2
n2v = Node2Vec(adjmat, 10, 128, 10, 80, 1, 2)
n2v.train(30, 0.05)
embeddings = np.array(n2v.get_embeddings())

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4, random_state=0,n_init=10).fit(embeddings)
labels = kmeans.labels_
plot_graph(G, labels)
# Out:
# INFO - 2023-10-26 20:28:49,838: collecting all words and their counts
# INFO - 2023-10-26 20:28:49,839: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-10-26 20:28:49,845: collected 77 word types from a corpus of 62370 raw words and 770 sentences
# INFO - 2023-10-26 20:28:49,845: Creating a fresh vocabulary
# INFO - 2023-10-26 20:28:49,845: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-10-26T20:28:49.845852', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 20:28:49,846: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 62370 word corpus (100.00% of original 62370, drops 0)', 'datetime': '2023-10-26T20:28:49.846159', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 20:28:49,846: deleting the raw counts dictionary of 77 items
# INFO - 2023-10-26 20:28:49,846: sample=0.001 downsamples 49 most-common words
# INFO - 2023-10-26 20:28:49,847: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 17358.686325551047 word corpus (27.8%% of prior 62370)', 'datetime': '2023-10-26T20:28:49.847123', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 20:28:49,847: estimated required memory for 77 words and 128 dimensions: 117348 bytes
# INFO - 2023-10-26 20:28:49,848: resetting layer weights
# INFO - 2023-10-26 20:28:49,849: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-10-26T20:28:49.849741', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'build_vocab'}
# INFO - 2023-10-26 20:28:49,850: Word2Vec lifecycle event {'msg': 'training model with 6 workers on 77 vocabulary and 128 features, using sg=1 hs=0 sample=0.001 negative=10 window=10 shrink_windows=True', 'datetime': '2023-10-26T20:28:49.850251', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'train'}
# INFO - 2023-10-26 20:28:49,933: EPOCH 0: training on 62370 raw words (17316 effective words) took 0.1s, 212235 effective words/s
# INFO - 2023-10-26 20:28:50,027: EPOCH 1: training on 62370 raw words (17632 effective words) took 0.1s, 191499 effective words/s
# INFO - 2023-10-26 20:28:50,130: EPOCH 2: training on 62370 raw words (17433 effective words) took 0.1s, 174130 effective words/s
# INFO - 2023-10-26 20:28:50,234: EPOCH 3: training on 62370 raw words (17387 effective words) took 0.1s, 172011 effective words/s
# INFO - 2023-10-26 20:28:50,341: EPOCH 4: training on 62370 raw words (17433 effective words) took 0.1s, 167475 effective words/s
# INFO - 2023-10-26 20:28:50,446: EPOCH 5: training on 62370 raw words (17607 effective words) took 0.1s, 170120 effective words/s
# INFO - 2023-10-26 20:28:50,549: EPOCH 6: training on 62370 raw words (17302 effective words) took 0.1s, 173160 effective words/s
# INFO - 2023-10-26 20:28:50,653: EPOCH 7: training on 62370 raw words (17479 effective words) took 0.1s, 170136 effective words/s
# INFO - 2023-10-26 20:28:50,755: EPOCH 8: training on 62370 raw words (17207 effective words) took 0.1s, 172968 effective words/s
# INFO - 2023-10-26 20:28:50,861: EPOCH 9: training on 62370 raw words (17398 effective words) took 0.1s, 167839 effective words/s
# INFO - 2023-10-26 20:28:50,862: Word2Vec lifecycle event {'msg': 'training on 623700 raw words (174194 effective words) took 1.0s, 172185 effective words/s', 'datetime': '2023-10-26T20:28:50.862281', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'train'}
# INFO - 2023-10-26 20:28:50,862: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=128, alpha=0.05>', 'datetime': '2023-10-26T20:28:50.862815', 'gensim': '4.3.2', 'python': '3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-87-generic-x86_64-with-glibc2.31', 'event': 'created'}

# %%
# Compute node degrees
node_degrees = dict(G.degree())

# Determine the maximum degree for scaling node sizes
max_degree = max(node_degrees.values())

# Define a scaling factor for node sizes
scale_factor = 200  # Adjust this as needed to control the node size

# Compute node sizes proportional to their degree
node_sizes = [scale_factor * node_degrees[node] / max_degree for node in G.nodes]

# Plot the graph with nodes sized by their degree
pos = nx.spring_layout(G)  # Use a layout algorithm that suits your needs
nx.draw(G, pos, with_labels=True, node_color=labels, cmap=plt.cm.rainbow, node_size=node_sizes)

# Add colorbar for node colors
sm = plt.cm.ScalarMappable(cmap=plt.cm.rainbow, norm=plt.Normalize(vmin=min(labels), vmax=max(labels)))
sm.set_array([])
plt.colorbar(sm, label='Cluster')
plt.show()
# Out:
# /tmp/ipykernel_13276/1576803452.py:20: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm, label='Cluster')
