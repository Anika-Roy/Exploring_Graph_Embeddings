# %% [markdown]
# # Deep Walk
#
# - Adjacency matrix is essentially a list of one-hot encoding vectors for each neighbour of a given node.
# - Takes graph as input and returns the latent representation as output.
#
# ## Parallels with NLP
# ||Networks|NLP|
# |---|--------|---|
# |Vocabulary|Nodes|Words|
# |Sentence|Random Walks|Sentence/Document|
#
# **Note:** for a window length of $w$, we will see $2w + 1$ words at a time
#
# ## Skipgram
# > Given sentence as `we iterate over all the vertices` and window length `w`. <br>
# > For the word `over` predict `all`, `the`, `we` and `iterate`.

# %%
# %pip install numpy
# %pip install matplotlib
# %pip install heapq

import numpy as np
import matplotlib.pyplot as plt
import heapq

# %%
class DeepWalk:
        def __init__(self, graph : "list[list[int]]", window_size : int, embedding_size : int, walks_per_vertex : int, walk_length : int) -> None:
                """
                Initialize the DeepWalk model. This directly from the paper https://arxiv.org/pdf/1403.6652.pdf.

                Parameters
                ----------
                graph : list[list[int]]
                        The adjacency list to be embedded. This is a list of lists, where each list is a vertex and its neighbors.
                window_size : int
                        The window size for the skipgram model.
                embedding_size : int
                        The size of the embedding. The final output matrix will be of size |V| x embedding_size.
                walks_per_vertex : int
                        The number of walks to perform per vertex.
                walk_length : int
                        The length of each walk.
                """
                self.g = graph
                self.w = window_size
                self.d = embedding_size
                self.gamma = walks_per_vertex
                self.epochs = self.gamma
                self.t = walk_length
                self.n = len(graph)
                self.word2id = {i : i for i in range(self.n)}
                self.id2word = {i : i for i in range(self.n)}

        def _huffman_encode(self) -> "dict[int, str]":
                """
                Huffman encode the graph for hierarchical softmax.

                Returns
                -------
                
                """
                huffman_tree = dict()

                # Calculate the word frequencies in the graph
                word_frequencies = {}  # Initialize an empty dictionary to store word frequencies
                for vertex_neighbors in self.g:
                        for neighbor in vertex_neighbors:
                                if neighbor in word_frequencies:
                                        word_frequencies[neighbor] += 1
                                else:
                                        word_frequencies[neighbor] = 1

                # Construct a priority queue for Huffman tree construction
                priority_queue = [(-freq, int(word)) for word, freq in word_frequencies.items()]
                heapq.heapify(priority_queue)

                # Build the Huffman tree
                while len(priority_queue) > 1:
                        left, right = heapq.heappop(priority_queue), heapq.heappop(priority_queue)
                        merged_node = (left[0] + right[0], [left, right])
                        heapq.heappush(priority_queue, merged_node)

                # Assign binary codes to words in the Huffman tree
                def build_huffman_codes(node, code):
                        if isinstance(node[1], list):
                                build_huffman_codes(node[1][0], code + '0')
                                build_huffman_codes(node[1][1], code + '1')
                        else:
                                word = int(node[1])
                                huffman_tree[word] = code

                huffman_tree = {}  # Initialize an empty dictionary to store Huffman codes
                build_huffman_codes(priority_queue[0], '')  # Start building Huffman codes from the root node

                return huffman_tree


        def _random_walk(self, vertex : int) -> "list[int]":
                """
                Perform a random walk on the graph.

                Parameters
                ----------
                vertex : int
                        The vertex to start the random walk from.

                Returns
                -------
                list[int]
                        The random walk.
                """
                walk = [vertex]
                for _ in range(self.t - 1):
                        neighbors = self.g[walk[-1]]
                        walk.append(np.random.choice(neighbors))
                return walk
        
        def _skipgram(self, walk : "list[int]", learning_rate : float) -> None:
                """
                Perform the skipgram model.

                Parameters
                ----------
                walk : list[int]
                        The random walk to perform the skipgram model on.
                
                learning_rate : float
                        The learning rate for the model.
                """
                for i in self.t:
                        for j in range(max(0, i - self.w), min(self.t, i + self.w + 1)):
                                if i != j:
                                        # Get the word embedding for the current word
                                        word_embedding = self.embedding[walk[i]]

                                        # Get the word embedding for the context word
                                        context_word_embedding = self.embedding[walk[j]]

                                        # Calculate the dot product between the two embeddings
                                        dot_product = np.dot(word_embedding, context_word_embedding)

                                        # Calculate the probability of the context word given the current word
                                        # We will use the sigmoid function to calculate this probability
                                        probability = 1 / (1 + np.exp(-dot_product))

                                        # Calculate the error
                                        error = probability - self.huffman_tree[walk[j]]

                                        # Update the word embedding
                                        self.embedding[walk[i]] -= learning_rate * error * context_word_embedding


        def train(self, learning_rate : float) -> "list[list[float]]":
                """
                Train the DeepWalk model.

                Parameters
                ----------
                learning_rate : float
                        The learning rate for the model.

                Returns
                -------
                list[list[float]]
                        The embedding matrix.
                """
                
                # Initialize the embedding matrix.
                # We will use a uniform distribution to initialize the matrix.
                # The matrix will be of size |V| x d.
                # We will also normalize the matrix so that each row has unit norm.
                self.embedding = np.random.uniform(size=(self.n, self.d))
                self.embedding = self.embedding / np.linalg.norm(self.embedding, axis=1).reshape(-1, 1)

                # Huffman encoding the graph for hierarchical softmax.
                self.huffman_tree = self._huffman_encode()
                print(self.huffman_tree)
                
                # Train the model
                for epoch in range(1, self.epochs + 1):
                        # Get a random permutation of [1, n]
                        # This helps the SGD converge fast
                        permutation = np.random.permutation(self.n)

                        for vertex in permutation:
                                # Perform the random walk
                                walk = self._random_walk(vertex)

                                # Perform the skipgram model
                                self._skipgram(walk, learning_rate)

# %%
# %pip install networkx
import networkx as nx
# Out:
# Requirement already satisfied: networkx in /home/ujjwal-shake-her/.local/lib/python3.8/site-packages (3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
G = nx.karate_club_graph()
nx.draw(G, with_labels=True)

# %%
adjmat = nx.adjacency_matrix(G).todense()

dw = DeepWalk(adjmat, 2, 2, 10, 10)
dw.train(0.01)

print(dw.embedding)
# Out:
# {0: '0000000', 3: '0000001', 2: '000001', 4: '00001', 5: '0001', 1: '001', 6: '01', 7: '1'}
# [26  0 20  7 18 24 15 27  8 30  6 29 11 31  1 22 12 23 19 32 16 33 13  3
#   9 14 10  4  5 25 28 21 17  2]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> adjmat = nx.adjacency_matrix(G).todense()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> dw = DeepWalk(adjmat, 2, 2, 10, 10)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> dw.train(0.01)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> print(dw.embedding)
#
# /home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb Cell 6 line 1
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=165'>166</a> for j in range(max(0, i - self.w), min(self.t, i + self.w + 1)):
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=166'>167</a>         if i != j:
# --> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=167'>168</a>                 self._skipgram(walk, learning_rate)
#
# /home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=92'>93</a> def _skipgram(self, walk : "list[int]", learning_rate : float) -> None:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=93'>94</a>         """
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=94'>95</a>         Perform the skipgram model.
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=95'>96</a>
#    (...)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=102'>103</a>                 The learning rate for the model.
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=103'>104</a>         """
# --> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=104'>105</a>         for i in self.t:
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=105'>106</a>                 for j in range(max(0, i - self.w), min(self.t, i + self.w + 1)):
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=106'>107</a>                         if i != j:
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ujjwal-shake-her/M23_Code_Thingies/SMAI/projectProject/project-lmailmai/deepwalk.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=107'>108</a>                                 # Get the word embedding for the current word
#
# TypeError: 'int' object is not iterable
