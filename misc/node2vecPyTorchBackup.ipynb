# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
from sklearn.manifold import TSNE
from gensim.models import Word2Vec
import multiprocessing
import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", level=logging.INFO)

cores = multiprocessing.cpu_count() # Count the number of cores in a computer
print(cores)
# Out:
# 12

# %% [markdown]
# # Implementing the Node2Vec paradigm
# ## Algorithm
# - We are given an adjacency matrix -> this acts as a set of rules (vocabulary)
# - We are going to generate linear chains to be able to predict the context/neighborhood of a given node
# - So, using the adjacency matrix, we generate many random walks of a fixed length.
# - The random walks will become our dataset to feed and train the `SkipGram` model.

# %%
class Node2Vec():
        def __init__(
                        self, 
                        graph : "list[list[int]]", 
                        window_size : int, 
                        embedding_size : int, 
                        walks_per_vertex : int, 
                        walk_length : int,
                        p : float,
                        q : float
                ) -> None:
                """
                Initialize the DeepWalk model. This directly from the paper https://arxiv.org/pdf/1403.6652.pdf.

                Parameters
                ----------
                graph : list[list[int]]
                        The adjacency list to be embedded. This is a list of lists, where each list is a vertex and its neighbors.
                window_size : int
                        The window size for the skipgram model.
                embedding_size : int
                        The size of the embedding. The final output matrix will be of size |V| x embedding_size.
                walks_per_vertex : int
                        The number of walks to perform per vertex.
                walk_length : int
                        The length of each walk.
                p : float
                        The return parameter.
                q : float
                        The in-out parameter.

                Methods
                -------
                generate_n_walks()
                        Generate n walks from the graph.
                train()
                        Train the model.
                update()
                        Feed model new walks.
                get_embeddings()
                        Return the embeddings.
                """

                # DeepWalk parameters
                self.g = graph
                self.w = window_size
                self.d = embedding_size
                self.gamma = walks_per_vertex
                self.epochs = self.gamma
                self.t = walk_length
                self.n = len(graph)
                self.p = p
                self.q = q

        def second_order_biased_random_walk(
                        self,
                        adj_mat : 'list[list[int]]', 
                        walk_len : 'int', 
                        start_node : 'int', 
                        return_parameter :'float', 
                        in_out_parameter : 'float'
                        ) -> np.array:
                """
                Return a walk based on a 2nd order Markov Chain like transition.

                Parameters
                ----------
                adj_mat : list[list[int]]
                        Adjacency matrix of the graph.
                walk_len : int
                        Length of the random walk.
                start_node : int
                        Starting node of the random walk.
                return_parameter : float
                        The value of the "p" parameter
                in_out_parameter : float
                        The value of the "q" parameter
                
                Returns
                -------
                np.array
                        List of nodes in the random walk.  
                
                """
                # Array to store the walk
                walk = [
                        start_node, # Extra node to help uniformly sample the second node
                        start_node # The actual walk we will return is walk
                ]

                # Make an adjacency list to easily 
                # sample the neighbors of a node.
                adj_list = [] # list of [node, weight]
                for i in range(len(adj_mat)):
                        neighbors = np.where(adj_mat[i] > 0)[0]  # Get neighbor indices
                        weights = adj_mat[i, neighbors]  # Get corresponding edge weights
                        adj_list.append(list(zip(neighbors, weights)))

                # Keep walking for walk_len epochs
                for epochs in range(walk_len):
                        # 1) Assign a value of 1 / in_out 
                        #    to all neighbours of walk[-1]
                        # 2) Overwrite the value of all 
                        #    neighbours of walk[-2] with 1 
                        # 3) Overwrite walk[-2] by 1
                        # 4) Multiply each element by the 
                        #    weight of the corresponding edge. 
                        # Feed it to np.random.choice

                        # Current and Parent node 
                        curr_node = walk[-1]
                        prev_node = walk[-2]

                        # Using the parent_node id get the neighbours and their weights
                        neighbors, weights = zip(*adj_list[curr_node])
                        prev_neighbors, prev_weights = zip(*adj_list[prev_node])

                        # Get boolean arrays to mark current neighbours as previous node's neighbours
                        is_prev_neighbor = np.isin(neighbors, prev_neighbors)
                        is_prev_node = np.isin(prev_node, neighbors)
                        
                        # Calculate probabilities based on the return and in-out parameters
                        probabilities = np.zeros(len(neighbors), dtype=np.float64)
                        
                        probabilities[is_prev_node] = 1.0 / return_parameter
                        probabilities[is_prev_neighbor] = 1.0
                        probabilities[~(is_prev_node | is_prev_neighbor)] = 1.0 / in_out_parameter

                        # Normalize the probabilities
                        probabilities /= np.sum(probabilities)

                        # Multiply each element by the weight of the corresponding edge
                        # weighted_probabilities = probabilities * weights
                        weighted_probabilities = probabilities

                        # Choose the next node based on the probabilities
                        next_node = np.random.choice(neighbors, p=weighted_probabilities / np.sum(weighted_probabilities))

                        walk.append(next_node)


                return np.array(walk[1:])

        def generate_n_walks(self, num_iters : int) -> 'list[list[str]]':
                """
                Generate a list of num_iters random walks. These will be used to train the model

                Parameters
                ----------
                num_iters : int
                        Number of walks to generate.

                Returns
                -------
                np.ndarray
                        List of random walks.
                """

                # List to store the walks
                walks = []

                # For each vertex in the graph
                for vertex in range(self.n):
                        # Generate gamma walks of length t
                        for _ in range(self.gamma):
                                walks.append(self.second_order_biased_random_walk(self.g, self.t, vertex, self.p, self.q))

                walks = [[str(node) for node in walk] for walk in walks]

                return walks

        def train(self, epochs : int, lr : float) -> None:
                """
                Train the model.

                Parameters
                ----------
                epochs : int
                        Number of epochs to train the model for.
                lr : float
                        Learning rate for the optimizer.                
                """

                # Generate many walks
                walks = self.generate_n_walks(self.gamma)

                # Initialize the model
                self.model = Word2Vec(
                        walks,
                        negative= 10,
                        sg=1,
                        alpha=0.05,
                        epochs=self.epochs, 
                        vector_size=self.d,        # embedding dimension
                        window=self.w,             # context window size
                        min_count=0,
                        workers=cores-2
                )

        def get_embeddings(self) -> np.ndarray:
                """
                Return the embeddings.

                Returns
                -------
                np.ndarray
                        Embeddings.
                """
                return [self.model.wv[str(n)] for n in range(self.n)]
        
        def plot_embeddings(self, num_dimensions : int, gt_labels : 'list[str]') -> None:
                """
                Plot the embeddings.

                Parameters
                ----------
                num_dimensions : int
                        Number of dimensions to plot.
                gt_labels : list[str]
                        List of ground truth labels.
                """
                embeddings = np.array(self.get_embeddings())

                # dimensionality reduction to 2 dimensions using t-SNE for visualization
                embeddings = TSNE(n_components=2).fit_transform(embeddings)

                # Convert gt into numbers
                gt_labels = np.array(gt_labels)

                # Iterate over all labels and assign them an integer
                for i, label in enumerate(np.unique(gt_labels)):
                        gt_labels[gt_labels == label] = i
                gt_labels = gt_labels.astype(int)

                # plot the embeddings
                plt.figure(figsize=(6,6))
                plt.scatter(embeddings[:,0], embeddings[:,1], c=gt_labels)

                # Plot node numbers
                for i in range(len(embeddings)):
                        plt.annotate(i , (embeddings[i,0], embeddings[i,1]))
                        
                plt.show()

# %%
G = nx.karate_club_graph()
gt = []
for node in G.nodes():
    gt.append(G.nodes[node]['club'])

# Convert gt into numbers
gt_labels = np.array(gt)

# Iterate over all labels and assign them an integer
for i, label in enumerate(np.unique(gt_labels)):
        gt_labels[gt_labels == label] = i
gt_labels = gt_labels.astype(int)

nx.draw(G, with_labels=True, node_color=gt_labels, cmap=plt.cm.rainbow)
adjmat = nx.adjacency_matrix(G).todense()

# %%
# adjmat , window_size , embedding_size , walks_per_vertex , walk_length , p , q
n2v = Node2Vec(adjmat, 10, 128, 10, 80, 1, 1)

# %%
n2v.train(30, 0.05)
# Out:
# INFO - 2023-10-26 10:29:10,233: collecting all words and their counts
# INFO - 2023-10-26 10:29:10,235: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-10-26 10:29:10,244: collected 34 word types from a corpus of 27540 raw words and 340 sentences
# INFO - 2023-10-26 10:29:10,245: Creating a fresh vocabulary
# INFO - 2023-10-26 10:29:10,247: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 34 unique words (100.00% of original 34, drops 0)', 'datetime': '2023-10-26T10:29:10.247426', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 10:29:10,248: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 27540 word corpus (100.00% of original 27540, drops 0)', 'datetime': '2023-10-26T10:29:10.248637', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 10:29:10,250: deleting the raw counts dictionary of 34 items
# INFO - 2023-10-26 10:29:10,253: sample=0.001 downsamples 34 most-common words
# INFO - 2023-10-26 10:29:10,255: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 5704.638893546648 word corpus (20.7%% of prior 27540)', 'datetime': '2023-10-26T10:29:10.255435', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 10:29:10,257: estimated required memory for 34 words and 128 dimensions: 51816 bytes
# INFO - 2023-10-26 10:29:10,259: resetting layer weights
# INFO - 2023-10-26 10:29:10,261: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-10-26T10:29:10.261912', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-10-26 10:29:10,263: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 34 vocabulary and 128 features, using sg=1 hs=0 sample=0.001 negative=10 window=10 shrink_windows=True', 'datetime': '2023-10-26T10:29:10.263175', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-10-26 10:29:10,327: EPOCH 0: training on 27540 raw words (5700 effective words) took 0.1s, 108696 effective words/s
# INFO - 2023-10-26 10:29:10,384: EPOCH 1: training on 27540 raw words (5628 effective words) took 0.0s, 115947 effective words/s
# INFO - 2023-10-26 10:29:10,443: EPOCH 2: training on 27540 raw words (5699 effective words) took 0.0s, 114683 effective words/s
# INFO - 2023-10-26 10:29:10,501: EPOCH 3: training on 27540 raw words (5724 effective words) took 0.0s, 118935 effective words/s
# INFO - 2023-10-26 10:29:10,559: EPOCH 4: training on 27540 raw words (5754 effective words) took 0.0s, 117172 effective words/s
# INFO - 2023-10-26 10:29:10,617: EPOCH 5: training on 27540 raw words (5765 effective words) took 0.0s, 124202 effective words/s
# INFO - 2023-10-26 10:29:10,674: EPOCH 6: training on 27540 raw words (5662 effective words) took 0.0s, 117529 effective words/s
# INFO - 2023-10-26 10:29:10,729: EPOCH 7: training on 27540 raw words (5608 effective words) took 0.0s, 120227 effective words/s
# INFO - 2023-10-26 10:29:10,786: EPOCH 8: training on 27540 raw words (5669 effective words) took 0.0s, 118780 effective words/s
# INFO - 2023-10-26 10:29:10,842: EPOCH 9: training on 27540 raw words (5732 effective words) took 0.0s, 117724 effective words/s
# INFO - 2023-10-26 10:29:10,844: Word2Vec lifecycle event {'msg': 'training on 275400 raw words (56941 effective words) took 0.6s, 98216 effective words/s', 'datetime': '2023-10-26T10:29:10.844164', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-10-26 10:29:10,845: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=34, vector_size=128, alpha=0.05>', 'datetime': '2023-10-26T10:29:10.845566', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}

# %%
n2v.plot_embeddings(2, gt)
# Out:
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ## Do K-clustering with `k = 4`

# %%
# getting the embeddings from the model
embeddings = np.array(n2v.get_embeddings())

from sknetwork.clustering import Louvain, get_modularity
import scipy.sparse as sp
from sknetwork.visualization import svg_graph, svg_bigraph

louvain = Louvain()
labels = louvain.fit_predict(adjmat)

# %%
G = nx.karate_club_graph()
nx.draw(G, with_labels=True, node_color=labels, cmap=plt.cm.rainbow)
adjmat = nx.adjacency_matrix(G).todense()

# %%
n2v.plot_embeddings(2, labels)
# Out:
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
G = nx.les_miserables_graph()
adjmat = nx.adjacency_matrix(G).todense()

# Encode the names to ids
name2id = {}
id2name = {}
for i, name in enumerate(G.nodes()):
    name2id[name] = i
    id2name[i] = name

# %%
G = nx.les_miserables_graph()
adjmat = nx.adjacency_matrix(G).todense()

# Compute node degrees
node_degrees = dict(G.degree())

# Determine the maximum degree for scaling node sizes
max_degree = max(node_degrees.values())

# Define a scaling factor for node sizes
scale_factor = 200  # Adjust this as needed to control the node size

# Compute node sizes proportional to their degree
node_sizes = [scale_factor * node_degrees[node] / max_degree for node in G.nodes]

# Plot the graph with nodes sized by their degree
pos = nx.spring_layout(G)  # Use a layout algorithm that suits your needs
nx.draw(G, pos, cmap=plt.cm.rainbow, node_size=node_sizes)

# Add colorbar for node colors
sm = plt.cm.ScalarMappable(cmap=plt.cm.rainbow, norm=plt.Normalize(vmin=min(labels), vmax=max(labels)))
sm.set_array([])
plt.colorbar(sm, label='Cluster')
plt.show()

# %%
# adjmat , window_size , embedding_size , walks_per_vertex , walk_length , p , q
n2v = Node2Vec(adjmat, 10, 128, 10, 80, 1, 0.5)
n2v.train(30, 0.05)
# Out:
# INFO - 2023-10-26 10:43:21,358: collecting all words and their counts
# INFO - 2023-10-26 10:43:21,359: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-10-26 10:43:21,378: collected 77 word types from a corpus of 62370 raw words and 770 sentences
# INFO - 2023-10-26 10:43:21,380: Creating a fresh vocabulary
# INFO - 2023-10-26 10:43:21,381: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-10-26T10:43:21.381773', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 10:43:21,383: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 62370 word corpus (100.00% of original 62370, drops 0)', 'datetime': '2023-10-26T10:43:21.382962', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 10:43:21,385: deleting the raw counts dictionary of 77 items
# INFO - 2023-10-26 10:43:21,386: sample=0.001 downsamples 67 most-common words
# INFO - 2023-10-26 10:43:21,387: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 20413.64652480545 word corpus (32.7%% of prior 62370)', 'datetime': '2023-10-26T10:43:21.387878', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-10-26 10:43:21,391: estimated required memory for 77 words and 128 dimensions: 117348 bytes
# INFO - 2023-10-26 10:43:21,392: resetting layer weights
# INFO - 2023-10-26 10:43:21,395: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-10-26T10:43:21.395544', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-10-26 10:43:21,396: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 128 features, using sg=1 hs=0 sample=0.001 negative=10 window=10 shrink_windows=True', 'datetime': '2023-10-26T10:43:21.396839', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-10-26 10:43:21,538: EPOCH 0: training on 62370 raw words (20197 effective words) took 0.1s, 155905 effective words/s
# INFO - 2023-10-26 10:43:21,666: EPOCH 1: training on 62370 raw words (20400 effective words) took 0.1s, 171497 effective words/s
# INFO - 2023-10-26 10:43:21,825: EPOCH 2: training on 62370 raw words (20249 effective words) took 0.1s, 136485 effective words/s
# INFO - 2023-10-26 10:43:21,971: EPOCH 3: training on 62370 raw words (20615 effective words) took 0.1s, 150928 effective words/s
# INFO - 2023-10-26 10:43:22,118: EPOCH 4: training on 62370 raw words (20465 effective words) took 0.1s, 151036 effective words/s
# INFO - 2023-10-26 10:43:22,288: EPOCH 5: training on 62370 raw words (20322 effective words) took 0.2s, 126739 effective words/s
# INFO - 2023-10-26 10:43:22,438: EPOCH 6: training on 62370 raw words (20505 effective words) took 0.1s, 148413 effective words/s
# INFO - 2023-10-26 10:43:22,590: EPOCH 7: training on 62370 raw words (20325 effective words) took 0.1s, 141821 effective words/s
# INFO - 2023-10-26 10:43:22,754: EPOCH 8: training on 62370 raw words (20566 effective words) took 0.2s, 133938 effective words/s
# INFO - 2023-10-26 10:43:22,926: EPOCH 9: training on 62370 raw words (20486 effective words) took 0.2s, 130488 effective words/s
# INFO - 2023-10-26 10:43:22,928: Word2Vec lifecycle event {'msg': 'training on 623700 raw words (204130 effective words) took 1.5s, 133369 effective words/s', 'datetime': '2023-10-26T10:43:22.928477', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-10-26 10:43:22,929: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=128, alpha=0.05>', 'datetime': '2023-10-26T10:43:22.929742', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}

# %%
# Do clustering after tSNE to get gt labels
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.metrics import normalized_mutual_info_score
from sklearn.metrics import adjusted_rand_score

# Get the embeddings
embeddings = np.array(n2v.get_embeddings())

# dimensionality reduction to 2 dimensions using t-SNE for visualization
embeddings = TSNE(n_components=2).fit_transform(embeddings)

# Do clustering
kmeans = KMeans(n_clusters=6, random_state=0).fit(embeddings)

# Get the labels
labels = kmeans.labels_

# Plot the graph with nodes colored by their cluster and size proportional to degree
pos = nx.spring_layout(G)  # Use a layout algorithm that suits your needs
nx.draw(G, pos, cmap=plt.cm.rainbow, node_color=labels, node_size=node_sizes)

# Add colorbar for node colors
sm = plt.cm.ScalarMappable(cmap=plt.cm.rainbow, norm=plt.Normalize(vmin=min(labels), vmax=max(labels)))
sm.set_array([])
plt.colorbar(sm, label='Cluster')
plt.show()
# Out:
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
