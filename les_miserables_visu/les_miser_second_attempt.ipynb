# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
from sklearn.manifold import TSNE
from gensim.models import Word2Vec
import numpy.random as npr
import multiprocessing
import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", level=logging.INFO)

cores = multiprocessing.cpu_count() # Count the number of cores in a computer
print(cores)
# Out:
# 12

# %% [markdown]
# # Implementing the Node2Vec paradigm
# ## Algorithm
# - We are given an adjacency matrix -> this acts as a set of rules (vocabulary)
# - We are going to generate linear chains to be able to predict the context/neighborhood of a given node
# - So, using the adjacency matrix, we generate many random walks of a fixed length.
# - The random walks will become our dataset to feed and train the `SkipGram` model.

# %%
class Node2Vec():
        def __init__(
                        self, 
                        graph : "list[list[int]]", 
                        window_size : int, 
                        embedding_size : int, 
                        walks_per_vertex : int, 
                        walk_length : int,
                        p : float,
                        q : float
                ) -> None:
                """
                Initialize the DeepWalk model. This directly from the paper https://arxiv.org/pdf/1403.6652.pdf.

                Parameters
                ----------
                graph : list[list[int]]
                        The adjacency list to be embedded. This is a list of lists, where each list is a vertex and its neighbors.
                window_size : int
                        The window size for the skipgram model.
                embedding_size : int
                        The size of the embedding. The final output matrix will be of size |V| x embedding_size.
                walks_per_vertex : int
                        The number of walks to perform per vertex.
                walk_length : int
                        The length of each walk.
                p : float
                        The return parameter.
                q : float
                        The in-out parameter.

                Methods
                -------
                generate_n_walks()
                        Generate n walks from the graph.
                train()
                        Train the model.
                update()
                        Feed model new walks.
                get_embeddings()
                        Return the embeddings.
                """

                # DeepWalk parameters
                self.g = graph
                self.w = window_size
                self.d = embedding_size
                self.gamma = walks_per_vertex
                self.epochs = self.gamma
                self.t = walk_length
                self.n = len(graph)
                self.p = p
                self.q = q
                
                # Cutoffs for sampling
                self.p0 = 1 / self.p / max(1, self.p, self.q)
                self.p1 = 1/  max(1, self.p, self.q)
                self.p2 = 1 / self.q / max(1, self.p, self.q)
                
                # Make the adjacency list using the graph
                self.adj_list = []
                for i in range(len(self.g)):
                    neighbors = np.where(self.g[i] > 0)[0]  # Get neighbor indices
                    weights = self.g[i, neighbors]  # Get corresponding edge weights
    
                    # Sort neighbors and weights by weight
                    sorted_neighbors_weights = sorted(zip(neighbors, weights), key=lambda x: x[0])
                    sorted_neighbors, sorted_weights = zip(*sorted_neighbors_weights)

                    self.adj_list.append(list(zip(sorted_neighbors, sorted_weights / np.sum(sorted_weights))))
        
        def get_random_neighbour(self, vertex : 'int') -> 'int':
                """
                Fetches a random neighbour of a given vertex
                by sampling on the basis of the edge weights
                
                Parameters
                ----------
                vertex : int
                        The vertex whose neighbour we will sample
                        
                Returns
                -------
                int
                        The neighbour that was sampled
                """
                # Sample a neighbour with probability proportional
                # to the edge weight from vertex --> neighbour
                neighbours, weights = zip(*self.adj_list[vertex])
                
                # Sample a vertex with probability proportional 
                # to the weight of the edge joining it.
                return np.random.choice(neighbours, p=weights)
                    
        def second_order_biased_random_walk(
                        self,
                        adj_mat : 'list[list[int]]', 
                        walk_len : 'int', 
                        start_node : 'int', 
                        return_parameter :'float', 
                        in_out_parameter : 'float'
                        ) -> np.array:
                """
                Return a walk based on a 2nd order Markov Chain like transition.

                Parameters
                ----------
                adj_mat : list[list[int]]
                        Adjacency matrix of the graph.
                walk_len : int
                        Length of the random walk.
                start_node : int
                        Starting node of the random walk.
                return_parameter : float
                        The value of the "p" parameter
                in_out_parameter : float
                        The value of the "q" parameter
                
                Returns
                -------
                np.array
                        List of nodes in the random walk.  
                
                """
                # Array to store the walk
                walk = [
                        start_node,
                        self.get_random_neighbour(start_node) # The prev_node is never Null
                ]

                # Generate the rest of the walk
                for i in range(2, walk_len):
                    # Variable to check whether we added to walk
                    found = False
                    
                    # Kep running until sampled in the red region
                    while not found:
                        new_node = self.get_random_neighbour(walk[-1])
                        r = np.random.rand()
                        
                        # Check if we will go back to the same node
                        if new_node == walk[-2]:
                            if r < self.p0:
                                found = True
                        
                        # Check if we are going to move by a distance of 1
                        elif self.g[walk[-2]][new_node]:
                            if r < self.p1:
                                found = True
                                    
                        else: # So we are moving by a distance of 2
                            if r < self.p2:
                                found = True
                                
                    walk.append(new_node)
            
                return walk

        def generate_n_walks(self, num_iters : int) -> 'list[list[str]]':
                """
                Generate a list of num_iters random walks. These will be used to train the model

                Parameters
                ----------
                num_iters : int
                        Number of walks to generate.

                Returns
                -------
                np.ndarray
                        List of random walks.
                """

                # List to store the walks
                walks = []

                # For each vertex in the graph
                for vertex in range(self.n):
                        # Generate gamma walks of length t starting from this "vertex"
                        for _ in range(self.gamma):
                                walks.append(self.second_order_biased_random_walk(self.g, self.t, vertex, self.p, self.q))

                walks = [[str(node) for node in walk] for walk in walks]

                return walks

        def train(self, epochs : int, lr : float) -> None:
                """
                Train the model.

                Parameters
                ----------
                epochs : int
                        Number of epochs to train the model for.
                lr : float
                        Learning rate for the optimizer.                
                """          
                # Generate many walks
                walks = self.generate_n_walks(self.gamma)

                # Initialize the model
                self.model = Word2Vec(
                        walks,
                        negative= 10,
                        sg=1,
                        alpha=0.05,
                        epochs=epochs, 
                        vector_size=self.d,        # embedding dimension
                        window=self.w,             # context window size
                        min_count=0,
                        workers=cores-2
                )

        def get_embeddings(self) -> np.ndarray:
                """
                Return the embeddings.

                Returns
                -------
                np.ndarray
                        Embeddings.
                """
                return [self.model.wv[str(n)] for n in range(self.n)]
        
        def plot_embeddings(self, num_dimensions : int, gt_labels : 'list[str]') -> None:
                """
                Plot the embeddings.

                Parameters
                ----------
                num_dimensions : int
                        Number of dimensions to plot.
                gt_labels : list[str]
                        List of ground truth labels.
                """
                embeddings = np.array(self.get_embeddings())

                # dimensionality reduction to 2 dimensions using t-SNE for visualization
                embeddings = TSNE(n_components=2).fit_transform(embeddings)

                # Convert gt into numbers
                gt_labels = np.array(gt_labels)

                # Iterate over all labels and assign them an integer
                for i, label in enumerate(np.unique(gt_labels)):
                        gt_labels[gt_labels == label] = i
                gt_labels = gt_labels.astype(int)

                # plot the embeddings
                plt.figure(figsize=(6,6))
                plt.scatter(embeddings[:,0], embeddings[:,1], c=gt_labels)

                # Plot node numbers
                for i in range(len(embeddings)):
                        plt.annotate(i , (embeddings[i,0], embeddings[i,1]))
                        
                plt.show()

# %%
def plot_graph ( G , node_colours):
    plt.figure(figsize=(8,8))
    # scale node size by degree
    node_sizes = [v * 20 for v in dict(G.degree()).values()]
    nx.draw_networkx(G, with_labels=False, node_color= node_colours, node_size= node_sizes,edgecolors="black", alpha=0.9)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Showing DeepWalk

# %%
G = nx.les_miserables_graph()
# draw a graph with light blue nodes outlined with black and grey edges (without labels)
plot_graph(G, "lightblue")

adjmat = nx.adjacency_matrix(G).todense()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler

# Assuming 'adjmat' is your adjacency matrix

# Make 12 x 12 mini subplots with no space and axes
fig, axes = plt.subplots(12, 12, figsize=(6, 6), sharex=True, sharey=True)
plt.subplots_adjust(wspace=0, hspace=0)

# n2v = Node2Vec(adjmat, 10, 32, 20, 3, 1, 2)
n2v = Node2Vec(adjmat, 5, 32, 20, 3, 1, 2)

for i in range(12):
    for j in range(12):
        # Train a n2v
        n2v.train(20, 0.05)

        # Getting the embeddings from the model
        embeddings = np.array(n2v.get_embeddings())

        # Dimensionality reduction to 2 dimensions using t-SNE for visualization
        tsne = TSNE(n_components=2, random_state=42)
        embeddings_2d = tsne.fit_transform(embeddings)

        # Standard scale between 0-1
        scaler = MinMaxScaler()
        normalized_embeddings_2d = scaler.fit_transform(embeddings_2d)

        # Plot the embeddings
        axes[i, j].scatter(normalized_embeddings_2d[:, 0], normalized_embeddings_2d[:, 1], s=2, alpha=0.5)

        # Remove all ticks
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])

# save as high quality svg
plt.savefig('les_miserables_n2v_fail1.svg', format='svg', dpi=1200)

plt.show()
# Out:
# INFO - 2023-11-28 01:34:08,513: collecting all words and their counts
# INFO - 2023-11-28 01:34:08,514: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:34:08,515: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:34:08,516: Creating a fresh vocabulary
# INFO - 2023-11-28 01:34:08,516: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:34:08.516890', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:08,517: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:34:08.517303', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:08,517: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:34:08,518: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:34:08,518: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1560.1452151434498 word corpus (33.8%% of prior 4620)', 'datetime': '2023-11-28T01:34:08.518750', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:08,519: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:34:08,519: resetting layer weights
# INFO - 2023-11-28 01:34:08,522: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:34:08.522232', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:34:08,522: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:34:08.522718', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:08,825: EPOCH 0: training on 4620 raw words (1482 effective words) took 0.3s, 4967 effective words/s
# INFO - 2023-11-28 01:34:08,882: EPOCH 1: training on 4620 raw words (1505 effective words) took 0.0s, 751791 effective words/s
# INFO - 2023-11-28 01:34:09,107: EPOCH 2: training on 4620 raw words (1583 effective words) took 0.2s, 7634 effective words/s
# INFO - 2023-11-28 01:34:09,115: EPOCH 3: training on 4620 raw words (1582 effective words) took 0.0s, 694308 effective words/s
# INFO - 2023-11-28 01:34:09,122: EPOCH 4: training on 4620 raw words (1604 effective words) took 0.0s, 754638 effective words/s
# INFO - 2023-11-28 01:34:09,127: EPOCH 5: training on 4620 raw words (1559 effective words) took 0.0s, 920785 effective words/s
# INFO - 2023-11-28 01:34:09,132: EPOCH 6: training on 4620 raw words (1539 effective words) took 0.0s, 814625 effective words/s
# INFO - 2023-11-28 01:34:09,137: EPOCH 7: training on 4620 raw words (1531 effective words) took 0.0s, 960439 effective words/s
# INFO - 2023-11-28 01:34:09,142: EPOCH 8: training on 4620 raw words (1599 effective words) took 0.0s, 1004411 effective words/s
# INFO - 2023-11-28 01:34:09,147: EPOCH 9: training on 4620 raw words (1583 effective words) took 0.0s, 693818 effective words/s
# INFO - 2023-11-28 01:34:09,152: EPOCH 10: training on 4620 raw words (1589 effective words) took 0.0s, 900618 effective words/s
# INFO - 2023-11-28 01:34:09,158: EPOCH 11: training on 4620 raw words (1515 effective words) took 0.0s, 957042 effective words/s
# INFO - 2023-11-28 01:34:09,163: EPOCH 12: training on 4620 raw words (1547 effective words) took 0.0s, 986788 effective words/s
# INFO - 2023-11-28 01:34:09,168: EPOCH 13: training on 4620 raw words (1552 effective words) took 0.0s, 837133 effective words/s
# INFO - 2023-11-28 01:34:09,173: EPOCH 14: training on 4620 raw words (1556 effective words) took 0.0s, 886216 effective words/s
# INFO - 2023-11-28 01:34:09,349: EPOCH 15: training on 4620 raw words (1535 effective words) took 0.0s, 824965 effective words/s
# INFO - 2023-11-28 01:34:09,438: EPOCH 16: training on 4620 raw words (1563 effective words) took 0.0s, 556403 effective words/s
# INFO - 2023-11-28 01:34:09,797: EPOCH 17: training on 4620 raw words (1586 effective words) took 0.2s, 10546 effective words/s
# INFO - 2023-11-28 01:34:09,802: EPOCH 18: training on 4620 raw words (1530 effective words) took 0.0s, 894825 effective words/s
# INFO - 2023-11-28 01:34:09,808: EPOCH 19: training on 4620 raw words (1546 effective words) took 0.0s, 715307 effective words/s
# INFO - 2023-11-28 01:34:09,808: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (31086 effective words) took 1.3s, 24177 effective words/s', 'datetime': '2023-11-28T01:34:09.808973', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:09,809: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:34:09.809470', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:34:11,234: collecting all words and their counts
# INFO - 2023-11-28 01:34:11,235: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:34:11,237: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:34:11,238: Creating a fresh vocabulary
# INFO - 2023-11-28 01:34:11,238: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:34:11.238941', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:11,239: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:34:11.239549', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:11,240: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:34:11,241: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:34:11,242: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1560.822866350336 word corpus (33.8%% of prior 4620)', 'datetime': '2023-11-28T01:34:11.242055', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:11,244: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:34:11,244: resetting layer weights
# INFO - 2023-11-28 01:34:11,245: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:34:11.245727', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:34:11,246: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:34:11.246322', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:11,610: EPOCH 0: training on 4620 raw words (1467 effective words) took 0.0s, 39633 effective words/s
# INFO - 2023-11-28 01:34:11,615: EPOCH 1: training on 4620 raw words (1563 effective words) took 0.0s, 801929 effective words/s
# INFO - 2023-11-28 01:34:11,621: EPOCH 2: training on 4620 raw words (1567 effective words) took 0.0s, 922927 effective words/s
# INFO - 2023-11-28 01:34:11,626: EPOCH 3: training on 4620 raw words (1599 effective words) took 0.0s, 906085 effective words/s
# INFO - 2023-11-28 01:34:11,631: EPOCH 4: training on 4620 raw words (1533 effective words) took 0.0s, 965164 effective words/s
# INFO - 2023-11-28 01:34:11,636: EPOCH 5: training on 4620 raw words (1553 effective words) took 0.0s, 894197 effective words/s
# INFO - 2023-11-28 01:34:11,641: EPOCH 6: training on 4620 raw words (1603 effective words) took 0.0s, 970508 effective words/s
# INFO - 2023-11-28 01:34:11,646: EPOCH 7: training on 4620 raw words (1540 effective words) took 0.0s, 920063 effective words/s
# INFO - 2023-11-28 01:34:11,650: EPOCH 8: training on 4620 raw words (1552 effective words) took 0.0s, 937950 effective words/s
# INFO - 2023-11-28 01:34:11,655: EPOCH 9: training on 4620 raw words (1546 effective words) took 0.0s, 874527 effective words/s
# INFO - 2023-11-28 01:34:11,660: EPOCH 10: training on 4620 raw words (1543 effective words) took 0.0s, 927253 effective words/s
# INFO - 2023-11-28 01:34:11,664: EPOCH 11: training on 4620 raw words (1562 effective words) took 0.0s, 905706 effective words/s
# INFO - 2023-11-28 01:34:11,669: EPOCH 12: training on 4620 raw words (1570 effective words) took 0.0s, 954425 effective words/s
# INFO - 2023-11-28 01:34:11,674: EPOCH 13: training on 4620 raw words (1587 effective words) took 0.0s, 778606 effective words/s
# INFO - 2023-11-28 01:34:11,678: EPOCH 14: training on 4620 raw words (1540 effective words) took 0.0s, 867123 effective words/s
# INFO - 2023-11-28 01:34:11,683: EPOCH 15: training on 4620 raw words (1532 effective words) took 0.0s, 978171 effective words/s
# INFO - 2023-11-28 01:34:11,688: EPOCH 16: training on 4620 raw words (1560 effective words) took 0.0s, 915950 effective words/s
# INFO - 2023-11-28 01:34:11,693: EPOCH 17: training on 4620 raw words (1561 effective words) took 0.0s, 907343 effective words/s
# INFO - 2023-11-28 01:34:11,697: EPOCH 18: training on 4620 raw words (1605 effective words) took 0.0s, 2028885 effective words/s
# INFO - 2023-11-28 01:34:11,734: EPOCH 19: training on 4620 raw words (1533 effective words) took 0.0s, 745128 effective words/s
# INFO - 2023-11-28 01:34:11,735: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (31116 effective words) took 0.5s, 63643 effective words/s', 'datetime': '2023-11-28T01:34:11.735764', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:11,736: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:34:11.736396', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:34:12,050: collecting all words and their counts
# INFO - 2023-11-28 01:34:12,051: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:34:12,052: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:34:12,053: Creating a fresh vocabulary
# INFO - 2023-11-28 01:34:12,053: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:34:12.053937', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:12,054: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:34:12.054437', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:12,055: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:34:12,055: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:34:12,056: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1562.4449831002944 word corpus (33.8%% of prior 4620)', 'datetime': '2023-11-28T01:34:12.056030', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:12,056: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:34:12,057: resetting layer weights
# INFO - 2023-11-28 01:34:12,059: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:34:12.059357', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:34:12,059: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:34:12.059827', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:12,068: EPOCH 0: training on 4620 raw words (1505 effective words) took 0.0s, 841647 effective words/s
# INFO - 2023-11-28 01:34:12,073: EPOCH 1: training on 4620 raw words (1565 effective words) took 0.0s, 863970 effective words/s
# INFO - 2023-11-28 01:34:12,078: EPOCH 2: training on 4620 raw words (1554 effective words) took 0.0s, 983173 effective words/s
# INFO - 2023-11-28 01:34:12,083: EPOCH 3: training on 4620 raw words (1544 effective words) took 0.0s, 1000723 effective words/s
# INFO - 2023-11-28 01:34:12,088: EPOCH 4: training on 4620 raw words (1584 effective words) took 0.0s, 794901 effective words/s
# INFO - 2023-11-28 01:34:12,094: EPOCH 5: training on 4620 raw words (1560 effective words) took 0.0s, 885412 effective words/s
# INFO - 2023-11-28 01:34:12,099: EPOCH 6: training on 4620 raw words (1568 effective words) took 0.0s, 908183 effective words/s
# INFO - 2023-11-28 01:34:12,217: EPOCH 7: training on 4620 raw words (1540 effective words) took 0.0s, 610251 effective words/s
# INFO - 2023-11-28 01:34:12,809: EPOCH 8: training on 4620 raw words (1535 effective words) took 0.1s, 10725 effective words/s
# INFO - 2023-11-28 01:34:13,062: EPOCH 9: training on 4620 raw words (1549 effective words) took 0.0s, 820812 effective words/s
# INFO - 2023-11-28 01:34:13,067: EPOCH 10: training on 4620 raw words (1538 effective words) took 0.0s, 975682 effective words/s
# INFO - 2023-11-28 01:34:13,071: EPOCH 11: training on 4620 raw words (1599 effective words) took 0.0s, 997830 effective words/s
# INFO - 2023-11-28 01:34:13,076: EPOCH 12: training on 4620 raw words (1544 effective words) took 0.0s, 831800 effective words/s
# INFO - 2023-11-28 01:34:13,081: EPOCH 13: training on 4620 raw words (1571 effective words) took 0.0s, 974444 effective words/s
# INFO - 2023-11-28 01:34:13,086: EPOCH 14: training on 4620 raw words (1589 effective words) took 0.0s, 918308 effective words/s
# INFO - 2023-11-28 01:34:13,091: EPOCH 15: training on 4620 raw words (1533 effective words) took 0.0s, 923679 effective words/s
# INFO - 2023-11-28 01:34:13,096: EPOCH 16: training on 4620 raw words (1497 effective words) took 0.0s, 849940 effective words/s
# INFO - 2023-11-28 01:34:13,101: EPOCH 17: training on 4620 raw words (1527 effective words) took 0.0s, 808582 effective words/s
# INFO - 2023-11-28 01:34:13,106: EPOCH 18: training on 4620 raw words (1572 effective words) took 0.0s, 942971 effective words/s
# INFO - 2023-11-28 01:34:13,111: EPOCH 19: training on 4620 raw words (1558 effective words) took 0.0s, 966185 effective words/s
# INFO - 2023-11-28 01:34:13,112: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (31032 effective words) took 1.1s, 29501 effective words/s', 'datetime': '2023-11-28T01:34:13.112202', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:13,112: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:34:13.112656', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:34:13,429: collecting all words and their counts
# INFO - 2023-11-28 01:34:13,430: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:34:13,431: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:34:13,432: Creating a fresh vocabulary
# INFO - 2023-11-28 01:34:13,433: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:34:13.433923', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:13,434: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:34:13.434605', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:13,435: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:34:13,436: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:34:13,436: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1558.7184007035396 word corpus (33.7%% of prior 4620)', 'datetime': '2023-11-28T01:34:13.436737', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:13,437: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:34:13,438: resetting layer weights
# INFO - 2023-11-28 01:34:13,439: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:34:13.439570', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:34:13,440: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:34:13.440393', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:13,445: EPOCH 0: training on 4620 raw words (1493 effective words) took 0.0s, 826907 effective words/s
# INFO - 2023-11-28 01:34:13,556: EPOCH 1: training on 4620 raw words (1569 effective words) took 0.0s, 667149 effective words/s
# INFO - 2023-11-28 01:34:13,599: EPOCH 2: training on 4620 raw words (1521 effective words) took 0.0s, 774053 effective words/s
# INFO - 2023-11-28 01:34:13,605: EPOCH 3: training on 4620 raw words (1567 effective words) took 0.0s, 825562 effective words/s
# INFO - 2023-11-28 01:34:13,641: EPOCH 4: training on 4620 raw words (1540 effective words) took 0.0s, 48094 effective words/s
# INFO - 2023-11-28 01:34:13,645: EPOCH 5: training on 4620 raw words (1523 effective words) took 0.0s, 893112 effective words/s
# INFO - 2023-11-28 01:34:13,650: EPOCH 6: training on 4620 raw words (1547 effective words) took 0.0s, 998259 effective words/s
# INFO - 2023-11-28 01:34:13,655: EPOCH 7: training on 4620 raw words (1616 effective words) took 0.0s, 929266 effective words/s
# INFO - 2023-11-28 01:34:13,659: EPOCH 8: training on 4620 raw words (1552 effective words) took 0.0s, 996531 effective words/s
# INFO - 2023-11-28 01:34:13,664: EPOCH 9: training on 4620 raw words (1575 effective words) took 0.0s, 946295 effective words/s
# INFO - 2023-11-28 01:34:13,669: EPOCH 10: training on 4620 raw words (1544 effective words) took 0.0s, 798805 effective words/s
# INFO - 2023-11-28 01:34:13,674: EPOCH 11: training on 4620 raw words (1537 effective words) took 0.0s, 914194 effective words/s
# INFO - 2023-11-28 01:34:13,758: EPOCH 12: training on 4620 raw words (1600 effective words) took 0.0s, 629834 effective words/s
# INFO - 2023-11-28 01:34:13,764: EPOCH 13: training on 4620 raw words (1506 effective words) took 0.0s, 952250 effective words/s
# INFO - 2023-11-28 01:34:13,769: EPOCH 14: training on 4620 raw words (1536 effective words) took 0.0s, 707552 effective words/s
# INFO - 2023-11-28 01:34:13,775: EPOCH 15: training on 4620 raw words (1493 effective words) took 0.0s, 910594 effective words/s
# INFO - 2023-11-28 01:34:13,780: EPOCH 16: training on 4620 raw words (1628 effective words) took 0.0s, 832891 effective words/s
# INFO - 2023-11-28 01:34:13,784: EPOCH 17: training on 4620 raw words (1546 effective words) took 0.0s, 1016910 effective words/s
# INFO - 2023-11-28 01:34:13,789: EPOCH 18: training on 4620 raw words (1544 effective words) took 0.0s, 718930 effective words/s
# INFO - 2023-11-28 01:34:13,816: EPOCH 19: training on 4620 raw words (1611 effective words) took 0.0s, 859900 effective words/s
# INFO - 2023-11-28 01:34:13,817: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (31048 effective words) took 0.4s, 82432 effective words/s', 'datetime': '2023-11-28T01:34:13.817450', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:13,818: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:34:13.817990', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:34:14,147: collecting all words and their counts
# INFO - 2023-11-28 01:34:14,148: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:34:14,149: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:34:14,149: Creating a fresh vocabulary
# INFO - 2023-11-28 01:34:14,150: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:34:14.150733', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:14,151: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:34:14.151347', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:14,152: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:34:14,153: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:34:14,153: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1560.4867217243675 word corpus (33.8%% of prior 4620)', 'datetime': '2023-11-28T01:34:14.153632', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:14,154: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:34:14,155: resetting layer weights
# INFO - 2023-11-28 01:34:14,157: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:34:14.157642', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:34:14,158: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:34:14.158314', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:14,166: EPOCH 0: training on 4620 raw words (1468 effective words) took 0.0s, 1571898 effective words/s
# INFO - 2023-11-28 01:34:14,173: EPOCH 1: training on 4620 raw words (1573 effective words) took 0.0s, 638903 effective words/s
# INFO - 2023-11-28 01:34:14,179: EPOCH 2: training on 4620 raw words (1565 effective words) took 0.0s, 926258 effective words/s
# INFO - 2023-11-28 01:34:14,185: EPOCH 3: training on 4620 raw words (1559 effective words) took 0.0s, 669504 effective words/s
# INFO - 2023-11-28 01:34:14,191: EPOCH 4: training on 4620 raw words (1568 effective words) took 0.0s, 761605 effective words/s
# INFO - 2023-11-28 01:34:14,230: EPOCH 5: training on 4620 raw words (1612 effective words) took 0.0s, 45381 effective words/s
# INFO - 2023-11-28 01:34:14,237: EPOCH 6: training on 4620 raw words (1559 effective words) took 0.0s, 744457 effective words/s
# INFO - 2023-11-28 01:34:14,243: EPOCH 7: training on 4620 raw words (1557 effective words) took 0.0s, 625929 effective words/s
# INFO - 2023-11-28 01:34:14,249: EPOCH 8: training on 4620 raw words (1561 effective words) took 0.0s, 697424 effective words/s
# INFO - 2023-11-28 01:34:14,255: EPOCH 9: training on 4620 raw words (1497 effective words) took 0.0s, 662092 effective words/s
# INFO - 2023-11-28 01:34:14,300: EPOCH 10: training on 4620 raw words (1525 effective words) took 0.0s, 809141 effective words/s
# INFO - 2023-11-28 01:34:14,306: EPOCH 11: training on 4620 raw words (1524 effective words) took 0.0s, 850709 effective words/s
# INFO - 2023-11-28 01:34:14,311: EPOCH 12: training on 4620 raw words (1525 effective words) took 0.0s, 972190 effective words/s
# INFO - 2023-11-28 01:34:14,315: EPOCH 13: training on 4620 raw words (1603 effective words) took 0.0s, 1052146 effective words/s
# INFO - 2023-11-28 01:34:14,319: EPOCH 14: training on 4620 raw words (1525 effective words) took 0.0s, 1043205 effective words/s
# INFO - 2023-11-28 01:34:14,438: EPOCH 15: training on 4620 raw words (1602 effective words) took 0.0s, 775859 effective words/s
# INFO - 2023-11-28 01:34:14,542: EPOCH 16: training on 4620 raw words (1536 effective words) took 0.0s, 837476 effective words/s
# INFO - 2023-11-28 01:34:14,547: EPOCH 17: training on 4620 raw words (1564 effective words) took 0.0s, 848503 effective words/s
# INFO - 2023-11-28 01:34:14,553: EPOCH 18: training on 4620 raw words (1537 effective words) took 0.0s, 683325 effective words/s
# INFO - 2023-11-28 01:34:14,559: EPOCH 19: training on 4620 raw words (1510 effective words) took 0.0s, 783693 effective words/s
# INFO - 2023-11-28 01:34:14,560: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (30970 effective words) took 0.4s, 77158 effective words/s', 'datetime': '2023-11-28T01:34:14.560412', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:14,561: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:34:14.561004', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:34:14,879: collecting all words and their counts
# INFO - 2023-11-28 01:34:14,880: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:34:14,881: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:34:14,882: Creating a fresh vocabulary
# INFO - 2023-11-28 01:34:14,883: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:34:14.883288', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:14,883: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:34:14.883928', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:14,885: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:34:14,885: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:34:14,886: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1559.219819837428 word corpus (33.7%% of prior 4620)', 'datetime': '2023-11-28T01:34:14.886440', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:14,887: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:34:14,888: resetting layer weights
# INFO - 2023-11-28 01:34:14,891: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:34:14.891850', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:34:14,893: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:34:14.893001', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:14,898: EPOCH 0: training on 4620 raw words (1489 effective words) took 0.0s, 928919 effective words/s
# INFO - 2023-11-28 01:34:14,904: EPOCH 1: training on 4620 raw words (1558 effective words) took 0.0s, 879849 effective words/s
# INFO - 2023-11-28 01:34:14,909: EPOCH 2: training on 4620 raw words (1514 effective words) took 0.0s, 873460 effective words/s
# INFO - 2023-11-28 01:34:14,915: EPOCH 3: training on 4620 raw words (1565 effective words) took 0.0s, 885262 effective words/s
# INFO - 2023-11-28 01:34:14,921: EPOCH 4: training on 4620 raw words (1576 effective words) took 0.0s, 654837 effective words/s
# INFO - 2023-11-28 01:34:14,926: EPOCH 5: training on 4620 raw words (1574 effective words) took 0.0s, 1852711 effective words/s
# INFO - 2023-11-28 01:34:14,952: EPOCH 6: training on 4620 raw words (1571 effective words) took 0.0s, 841208 effective words/s
# INFO - 2023-11-28 01:34:14,958: EPOCH 7: training on 4620 raw words (1530 effective words) took 0.0s, 934497 effective words/s
# INFO - 2023-11-28 01:34:14,963: EPOCH 8: training on 4620 raw words (1522 effective words) took 0.0s, 874350 effective words/s
# INFO - 2023-11-28 01:34:14,969: EPOCH 9: training on 4620 raw words (1613 effective words) took 0.0s, 784847 effective words/s
# INFO - 2023-11-28 01:34:14,974: EPOCH 10: training on 4620 raw words (1525 effective words) took 0.0s, 957265 effective words/s
# INFO - 2023-11-28 01:34:14,979: EPOCH 11: training on 4620 raw words (1547 effective words) took 0.0s, 851800 effective words/s
# INFO - 2023-11-28 01:34:14,985: EPOCH 12: training on 4620 raw words (1595 effective words) took 0.0s, 738739 effective words/s
# INFO - 2023-11-28 01:34:14,990: EPOCH 13: training on 4620 raw words (1622 effective words) took 0.0s, 988536 effective words/s
# INFO - 2023-11-28 01:34:14,995: EPOCH 14: training on 4620 raw words (1518 effective words) took 0.0s, 833396 effective words/s
# INFO - 2023-11-28 01:34:15,027: EPOCH 15: training on 4620 raw words (1582 effective words) took 0.0s, 961606 effective words/s
# INFO - 2023-11-28 01:34:15,032: EPOCH 16: training on 4620 raw words (1578 effective words) took 0.0s, 953799 effective words/s
# INFO - 2023-11-28 01:34:15,037: EPOCH 17: training on 4620 raw words (1501 effective words) took 0.0s, 852532 effective words/s
# INFO - 2023-11-28 01:34:15,043: EPOCH 18: training on 4620 raw words (1613 effective words) took 0.0s, 941588 effective words/s
# INFO - 2023-11-28 01:34:15,047: EPOCH 19: training on 4620 raw words (1543 effective words) took 0.0s, 842307 effective words/s
# INFO - 2023-11-28 01:34:15,048: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (31136 effective words) took 0.2s, 200863 effective words/s', 'datetime': '2023-11-28T01:34:15.048806', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:15,049: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:34:15.049452', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:34:15,375: collecting all words and their counts
# INFO - 2023-11-28 01:34:15,375: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:34:15,377: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:34:15,377: Creating a fresh vocabulary
# INFO - 2023-11-28 01:34:15,378: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:34:15.378556', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:15,379: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:34:15.379066', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:15,379: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:34:15,381: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:34:15,381: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1561.8793783494177 word corpus (33.8%% of prior 4620)', 'datetime': '2023-11-28T01:34:15.381569', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:15,382: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:34:15,383: resetting layer weights
# INFO - 2023-11-28 01:34:15,384: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:34:15.384197', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:34:15,384: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:34:15.384819', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:15,390: EPOCH 0: training on 4620 raw words (1482 effective words) took 0.0s, 831786 effective words/s
# INFO - 2023-11-28 01:34:15,395: EPOCH 1: training on 4620 raw words (1519 effective words) took 0.0s, 974875 effective words/s
# INFO - 2023-11-28 01:34:15,399: EPOCH 2: training on 4620 raw words (1568 effective words) took 0.0s, 985794 effective words/s
# INFO - 2023-11-28 01:34:15,404: EPOCH 3: training on 4620 raw words (1604 effective words) took 0.0s, 896737 effective words/s
# INFO - 2023-11-28 01:34:15,409: EPOCH 4: training on 4620 raw words (1526 effective words) took 0.0s, 988803 effective words/s
# INFO - 2023-11-28 01:34:15,413: EPOCH 5: training on 4620 raw words (1608 effective words) took 0.0s, 980359 effective words/s
# INFO - 2023-11-28 01:34:15,418: EPOCH 6: training on 4620 raw words (1586 effective words) took 0.0s, 970620 effective words/s
# INFO - 2023-11-28 01:34:15,423: EPOCH 7: training on 4620 raw words (1520 effective words) took 0.0s, 986525 effective words/s
# INFO - 2023-11-28 01:34:15,427: EPOCH 8: training on 4620 raw words (1507 effective words) took 0.0s, 971450 effective words/s
# INFO - 2023-11-28 01:34:15,432: EPOCH 9: training on 4620 raw words (1546 effective words) took 0.0s, 843254 effective words/s
# INFO - 2023-11-28 01:34:15,437: EPOCH 10: training on 4620 raw words (1538 effective words) took 0.0s, 963976 effective words/s
# INFO - 2023-11-28 01:34:15,442: EPOCH 11: training on 4620 raw words (1522 effective words) took 0.0s, 942437 effective words/s
# INFO - 2023-11-28 01:34:15,447: EPOCH 12: training on 4620 raw words (1556 effective words) took 0.0s, 1001154 effective words/s
# INFO - 2023-11-28 01:34:15,451: EPOCH 13: training on 4620 raw words (1529 effective words) took 0.0s, 955623 effective words/s
# INFO - 2023-11-28 01:34:15,456: EPOCH 14: training on 4620 raw words (1539 effective words) took 0.0s, 804930 effective words/s
# INFO - 2023-11-28 01:34:15,461: EPOCH 15: training on 4620 raw words (1620 effective words) took 0.0s, 934020 effective words/s
# INFO - 2023-11-28 01:34:15,466: EPOCH 16: training on 4620 raw words (1605 effective words) took 0.0s, 846040 effective words/s
# INFO - 2023-11-28 01:34:15,484: EPOCH 17: training on 4620 raw words (1593 effective words) took 0.0s, 582400 effective words/s
# INFO - 2023-11-28 01:34:15,491: EPOCH 18: training on 4620 raw words (1596 effective words) took 0.0s, 792177 effective words/s
# INFO - 2023-11-28 01:34:15,497: EPOCH 19: training on 4620 raw words (1560 effective words) took 0.0s, 738687 effective words/s
# INFO - 2023-11-28 01:34:15,498: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (31124 effective words) took 0.1s, 275119 effective words/s', 'datetime': '2023-11-28T01:34:15.498530', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:15,499: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:34:15.499015', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:34:15,820: collecting all words and their counts
# INFO - 2023-11-28 01:34:15,821: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:34:15,822: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:34:15,822: Creating a fresh vocabulary
# INFO - 2023-11-28 01:34:15,823: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:34:15.823541', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:15,824: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:34:15.824003', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:15,825: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:34:15,825: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:34:15,826: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1561.6312975955389 word corpus (33.8%% of prior 4620)', 'datetime': '2023-11-28T01:34:15.826072', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:34:15,827: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:34:15,827: resetting layer weights
# INFO - 2023-11-28 01:34:15,828: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:34:15.828130', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:34:15,828: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:34:15.828587', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:34:15,834: EPOCH 0: training on 4620 raw words (1488 effective words) took 0.0s, 873565 effective words/s
# INFO - 2023-11-28 01:34:15,840: EPOCH 1: training on 4620 raw words (1571 effective words) took 0.0s, 822361 effective words/s
# INFO - 2023-11-28 01:34:15,844: EPOCH 2: training on 4620 raw words (1575 effective words) took 0.0s, 989909 effective words/s
# INFO - 2023-11-28 01:34:15,849: EPOCH 3: training on 4620 raw words (1521 effective words) took 0.0s, 914084 effective words/s
# INFO - 2023-11-28 01:34:15,854: EPOCH 4: training on 4620 raw words (1507 effective words) took 0.0s, 943779 effective words/s
# INFO - 2023-11-28 01:34:15,875: EPOCH 5: training on 4620 raw words (1539 effective words) took 0.0s, 837778 effective words/s
# INFO - 2023-11-28 01:34:15,900: EPOCH 6: training on 4620 raw words (1565 effective words) took 0.0s, 887811 effective words/s
# INFO - 2023-11-28 01:34:15,907: EPOCH 7: training on 4620 raw words (1540 effective words) took 0.0s, 923066 effective words/s
# INFO - 2023-11-28 01:34:15,925: EPOCH 8: training on 4620 raw words (1572 effective words) took 0.0s, 832746 effective words/s
# INFO - 2023-11-28 01:34:16,104: EPOCH 9: training on 4620 raw words (1650 effective words) took 0.1s, 14017 effective words/s
# INFO - 2023-11-28 01:34:16,112: EPOCH 10: training on 4620 raw words (1531 effective words) took 0.0s, 702619 effective words/s
# INFO - 2023-11-28 01:34:16,117: EPOCH 11: training on 4620 raw words (1550 effective words) took 0.0s, 895132 effective words/s
# INFO - 2023-11-28 01:34:16,123: EPOCH 12: training on 4620 raw words (1633 effective words) took 0.0s, 962450 effective words/s
# INFO - 2023-11-28 01:34:16,128: EPOCH 13: training on 4620 raw words (1520 effective words) took 0.0s, 974277 effective words/s
# INFO - 2023-11-28 01:34:16,132: EPOCH 14: training on 4620 raw words (1566 effective words) took 0.0s, 992118 effective words/s
# ...
# INFO - 2023-11-28 01:35:30,070: EPOCH 1: training on 4620 raw words (1578 effective words) took 0.0s, 657522 effective words/s
# INFO - 2023-11-28 01:35:30,077: EPOCH 2: training on 4620 raw words (1564 effective words) took 0.0s, 602595 effective words/s
# INFO - 2023-11-28 01:35:30,099: EPOCH 3: training on 4620 raw words (1539 effective words) took 0.0s, 625885 effective words/s
# INFO - 2023-11-28 01:35:30,105: EPOCH 4: training on 4620 raw words (1560 effective words) took 0.0s, 641975 effective words/s
# INFO - 2023-11-28 01:35:30,114: EPOCH 5: training on 4620 raw words (1537 effective words) took 0.0s, 555662 effective words/s
# INFO - 2023-11-28 01:35:30,121: EPOCH 6: training on 4620 raw words (1609 effective words) took 0.0s, 602136 effective words/s
# INFO - 2023-11-28 01:35:30,129: EPOCH 7: training on 4620 raw words (1536 effective words) took 0.0s, 643470 effective words/s
# INFO - 2023-11-28 01:35:30,179: EPOCH 8: training on 4620 raw words (1554 effective words) took 0.0s, 597231 effective words/s
# INFO - 2023-11-28 01:35:30,269: EPOCH 9: training on 4620 raw words (1557 effective words) took 0.0s, 815439 effective words/s
# INFO - 2023-11-28 01:35:30,275: EPOCH 10: training on 4620 raw words (1539 effective words) took 0.0s, 714572 effective words/s
# INFO - 2023-11-28 01:35:30,280: EPOCH 11: training on 4620 raw words (1531 effective words) took 0.0s, 734490 effective words/s
# INFO - 2023-11-28 01:35:30,364: EPOCH 12: training on 4620 raw words (1530 effective words) took 0.0s, 897597 effective words/s
# INFO - 2023-11-28 01:35:30,410: EPOCH 13: training on 4620 raw words (1580 effective words) took 0.0s, 688491 effective words/s
# INFO - 2023-11-28 01:35:30,416: EPOCH 14: training on 4620 raw words (1560 effective words) took 0.0s, 794161 effective words/s
# INFO - 2023-11-28 01:35:30,423: EPOCH 15: training on 4620 raw words (1573 effective words) took 0.0s, 534862 effective words/s
# INFO - 2023-11-28 01:35:30,450: EPOCH 16: training on 4620 raw words (1526 effective words) took 0.0s, 1863869 effective words/s
# INFO - 2023-11-28 01:35:30,581: EPOCH 17: training on 4620 raw words (1542 effective words) took 0.0s, 826927 effective words/s
# INFO - 2023-11-28 01:35:30,668: EPOCH 18: training on 4620 raw words (1539 effective words) took 0.0s, 591945 effective words/s
# INFO - 2023-11-28 01:35:30,762: EPOCH 19: training on 4620 raw words (1593 effective words) took 0.0s, 729000 effective words/s
# INFO - 2023-11-28 01:35:30,763: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (31032 effective words) took 0.7s, 43988 effective words/s', 'datetime': '2023-11-28T01:35:30.763446', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:30,764: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:35:30.764182', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:35:31,162: collecting all words and their counts
# INFO - 2023-11-28 01:35:31,162: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:35:31,164: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:35:31,164: Creating a fresh vocabulary
# INFO - 2023-11-28 01:35:31,165: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:35:31.165210', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:31,165: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:35:31.165719', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:31,167: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:35:31,169: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:35:31,170: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1560.6728550188323 word corpus (33.8%% of prior 4620)', 'datetime': '2023-11-28T01:35:31.170559', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:31,172: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:35:31,173: resetting layer weights
# INFO - 2023-11-28 01:35:31,174: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:35:31.174267', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:35:31,174: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:35:31.174779', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:31,180: EPOCH 0: training on 4620 raw words (1507 effective words) took 0.0s, 847184 effective words/s
# INFO - 2023-11-28 01:35:31,186: EPOCH 1: training on 4620 raw words (1543 effective words) took 0.0s, 931893 effective words/s
# INFO - 2023-11-28 01:35:31,193: EPOCH 2: training on 4620 raw words (1625 effective words) took 0.0s, 778241 effective words/s
# INFO - 2023-11-28 01:35:31,597: EPOCH 3: training on 4620 raw words (1574 effective words) took 0.0s, 630903 effective words/s
# INFO - 2023-11-28 01:35:31,604: EPOCH 4: training on 4620 raw words (1560 effective words) took 0.0s, 686162 effective words/s
# INFO - 2023-11-28 01:35:31,610: EPOCH 5: training on 4620 raw words (1532 effective words) took 0.0s, 841519 effective words/s
# INFO - 2023-11-28 01:35:31,617: EPOCH 6: training on 4620 raw words (1562 effective words) took 0.0s, 663838 effective words/s
# INFO - 2023-11-28 01:35:31,622: EPOCH 7: training on 4620 raw words (1537 effective words) took 0.0s, 886962 effective words/s
# INFO - 2023-11-28 01:35:31,629: EPOCH 8: training on 4620 raw words (1545 effective words) took 0.0s, 716568 effective words/s
# INFO - 2023-11-28 01:35:31,636: EPOCH 9: training on 4620 raw words (1579 effective words) took 0.0s, 616093 effective words/s
# INFO - 2023-11-28 01:35:31,644: EPOCH 10: training on 4620 raw words (1558 effective words) took 0.0s, 536837 effective words/s
# INFO - 2023-11-28 01:35:31,650: EPOCH 11: training on 4620 raw words (1572 effective words) took 0.0s, 654070 effective words/s
# INFO - 2023-11-28 01:35:31,658: EPOCH 12: training on 4620 raw words (1490 effective words) took 0.0s, 565099 effective words/s
# INFO - 2023-11-28 01:35:31,665: EPOCH 13: training on 4620 raw words (1572 effective words) took 0.0s, 611244 effective words/s
# INFO - 2023-11-28 01:35:31,672: EPOCH 14: training on 4620 raw words (1556 effective words) took 0.0s, 654367 effective words/s
# INFO - 2023-11-28 01:35:31,679: EPOCH 15: training on 4620 raw words (1549 effective words) took 0.0s, 611340 effective words/s
# INFO - 2023-11-28 01:35:31,686: EPOCH 16: training on 4620 raw words (1515 effective words) took 0.0s, 655894 effective words/s
# INFO - 2023-11-28 01:35:31,695: EPOCH 17: training on 4620 raw words (1590 effective words) took 0.0s, 517237 effective words/s
# INFO - 2023-11-28 01:35:31,702: EPOCH 18: training on 4620 raw words (1522 effective words) took 0.0s, 619010 effective words/s
# INFO - 2023-11-28 01:35:31,892: EPOCH 19: training on 4620 raw words (1590 effective words) took 0.0s, 649576 effective words/s
# INFO - 2023-11-28 01:35:31,893: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (31078 effective words) took 0.7s, 43305 effective words/s', 'datetime': '2023-11-28T01:35:31.893054', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:31,893: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:35:31.893539', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:35:32,214: collecting all words and their counts
# INFO - 2023-11-28 01:35:32,215: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:35:32,216: collected 77 word types from a corpus of 4620 raw words and 1540 sentences
# INFO - 2023-11-28 01:35:32,217: Creating a fresh vocabulary
# INFO - 2023-11-28 01:35:32,217: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:35:32.217750', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:32,218: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 4620 word corpus (100.00% of original 4620, drops 0)', 'datetime': '2023-11-28T01:35:32.218309', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:32,221: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:35:32,222: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:35:32,223: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1562.3806216964128 word corpus (33.8%% of prior 4620)', 'datetime': '2023-11-28T01:35:32.223568', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:32,225: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:35:32,225: resetting layer weights
# INFO - 2023-11-28 01:35:32,226: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:35:32.226731', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:35:32,227: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:35:32.227706', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:32,235: EPOCH 0: training on 4620 raw words (1508 effective words) took 0.0s, 588789 effective words/s
# INFO - 2023-11-28 01:35:32,576: EPOCH 1: training on 4620 raw words (1594 effective words) took 0.3s, 4746 effective words/s
# INFO - 2023-11-28 01:35:32,582: EPOCH 2: training on 4620 raw words (1656 effective words) took 0.0s, 741217 effective words/s
# INFO - 2023-11-28 01:35:32,588: EPOCH 3: training on 4620 raw words (1554 effective words) took 0.0s, 807310 effective words/s
# INFO - 2023-11-28 01:35:32,595: EPOCH 4: training on 4620 raw words (1569 effective words) took 0.0s, 630253 effective words/s
# INFO - 2023-11-28 01:35:32,602: EPOCH 5: training on 4620 raw words (1552 effective words) took 0.0s, 732502 effective words/s
# INFO - 2023-11-28 01:35:32,609: EPOCH 6: training on 4620 raw words (1551 effective words) took 0.0s, 864828 effective words/s
# INFO - 2023-11-28 01:35:32,616: EPOCH 7: training on 4620 raw words (1592 effective words) took 0.0s, 704069 effective words/s
# INFO - 2023-11-28 01:35:32,621: EPOCH 8: training on 4620 raw words (1513 effective words) took 0.0s, 747190 effective words/s
# INFO - 2023-11-28 01:35:33,096: EPOCH 9: training on 4620 raw words (1532 effective words) took 0.0s, 805168 effective words/s
# INFO - 2023-11-28 01:35:33,255: EPOCH 10: training on 4620 raw words (1563 effective words) took 0.0s, 740516 effective words/s
# INFO - 2023-11-28 01:35:33,262: EPOCH 11: training on 4620 raw words (1606 effective words) took 0.0s, 680563 effective words/s
# INFO - 2023-11-28 01:35:33,267: EPOCH 12: training on 4620 raw words (1572 effective words) took 0.0s, 1049326 effective words/s
# INFO - 2023-11-28 01:35:33,274: EPOCH 13: training on 4620 raw words (1568 effective words) took 0.0s, 730322 effective words/s
# INFO - 2023-11-28 01:35:33,281: EPOCH 14: training on 4620 raw words (1566 effective words) took 0.0s, 881934 effective words/s
# INFO - 2023-11-28 01:35:33,287: EPOCH 15: training on 4620 raw words (1577 effective words) took 0.0s, 797455 effective words/s
# INFO - 2023-11-28 01:35:33,292: EPOCH 16: training on 4620 raw words (1555 effective words) took 0.0s, 649573 effective words/s
# INFO - 2023-11-28 01:35:33,298: EPOCH 17: training on 4620 raw words (1537 effective words) took 0.0s, 896136 effective words/s
# INFO - 2023-11-28 01:35:33,303: EPOCH 18: training on 4620 raw words (1568 effective words) took 0.0s, 952258 effective words/s
# INFO - 2023-11-28 01:35:33,307: EPOCH 19: training on 4620 raw words (1557 effective words) took 0.0s, 860346 effective words/s
# INFO - 2023-11-28 01:35:33,308: Word2Vec lifecycle event {'msg': 'training on 92400 raw words (31290 effective words) took 1.1s, 28989 effective words/s', 'datetime': '2023-11-28T01:35:33.308367', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:33,308: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:35:33.308976', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler

# Assuming 'adjmat' is your adjacency matrix

# Make 12 x 12 mini subplots with no space and axes
fig, axes = plt.subplots(12, 12, figsize=(6, 6), sharex=True, sharey=True)
plt.subplots_adjust(wspace=0, hspace=0)

# n2v = Node2Vec(adjmat, 10, 32, 20, 3, 1, 2)
n2v = Node2Vec(adjmat, 5, 32, 10, 10, 1, 2)

for i in range(12):
    for j in range(12):
        # Train a n2v
        n2v.train(50, 0.05)

        # Getting the embeddings from the model
        embeddings = np.array(n2v.get_embeddings())

        # Dimensionality reduction to 2 dimensions using t-SNE for visualization
        tsne = TSNE(n_components=2, random_state=42)
        embeddings_2d = tsne.fit_transform(embeddings)

        # Standard scale between 0-1
        scaler = MinMaxScaler()
        normalized_embeddings_2d = scaler.fit_transform(embeddings_2d)

        # Plot the embeddings
        axes[i, j].scatter(normalized_embeddings_2d[:, 0], normalized_embeddings_2d[:, 1], s=2, alpha=0.5)

        # Remove all ticks
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])

# save as high quality svg
plt.savefig('les_miserables_n2v_fail2.svg', format='svg', dpi=1200)

plt.show()
# Out:
# INFO - 2023-11-28 01:35:43,035: collecting all words and their counts
# INFO - 2023-11-28 01:35:43,037: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:35:43,038: collected 77 word types from a corpus of 7700 raw words and 770 sentences
# INFO - 2023-11-28 01:35:43,039: Creating a fresh vocabulary
# INFO - 2023-11-28 01:35:43,039: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:35:43.039978', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:43,040: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 7700 word corpus (100.00% of original 7700, drops 0)', 'datetime': '2023-11-28T01:35:43.040563', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:43,041: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:35:43,041: sample=0.001 downsamples 61 most-common words
# INFO - 2023-11-28 01:35:43,042: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2416.3454364458694 word corpus (31.4%% of prior 7700)', 'datetime': '2023-11-28T01:35:43.042167', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:43,043: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:35:43,043: resetting layer weights
# INFO - 2023-11-28 01:35:43,045: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:35:43.045519', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:35:43,045: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:35:43.045961', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:43,053: EPOCH 0: training on 7700 raw words (2332 effective words) took 0.0s, 550484 effective words/s
# INFO - 2023-11-28 01:35:43,061: EPOCH 1: training on 7700 raw words (2439 effective words) took 0.0s, 490346 effective words/s
# INFO - 2023-11-28 01:35:43,069: EPOCH 2: training on 7700 raw words (2472 effective words) took 0.0s, 505903 effective words/s
# INFO - 2023-11-28 01:35:43,076: EPOCH 3: training on 7700 raw words (2363 effective words) took 0.0s, 562437 effective words/s
# INFO - 2023-11-28 01:35:43,084: EPOCH 4: training on 7700 raw words (2435 effective words) took 0.0s, 491569 effective words/s
# INFO - 2023-11-28 01:35:43,092: EPOCH 5: training on 7700 raw words (2443 effective words) took 0.0s, 514002 effective words/s
# INFO - 2023-11-28 01:35:43,099: EPOCH 6: training on 7700 raw words (2432 effective words) took 0.0s, 537390 effective words/s
# INFO - 2023-11-28 01:35:43,107: EPOCH 7: training on 7700 raw words (2461 effective words) took 0.0s, 511771 effective words/s
# INFO - 2023-11-28 01:35:43,115: EPOCH 8: training on 7700 raw words (2400 effective words) took 0.0s, 518494 effective words/s
# INFO - 2023-11-28 01:35:43,123: EPOCH 9: training on 7700 raw words (2447 effective words) took 0.0s, 496419 effective words/s
# INFO - 2023-11-28 01:35:43,131: EPOCH 10: training on 7700 raw words (2444 effective words) took 0.0s, 520612 effective words/s
# INFO - 2023-11-28 01:35:43,138: EPOCH 11: training on 7700 raw words (2401 effective words) took 0.0s, 560744 effective words/s
# INFO - 2023-11-28 01:35:43,145: EPOCH 12: training on 7700 raw words (2430 effective words) took 0.0s, 545351 effective words/s
# INFO - 2023-11-28 01:35:43,153: EPOCH 13: training on 7700 raw words (2434 effective words) took 0.0s, 550233 effective words/s
# INFO - 2023-11-28 01:35:43,161: EPOCH 14: training on 7700 raw words (2406 effective words) took 0.0s, 464157 effective words/s
# INFO - 2023-11-28 01:35:43,169: EPOCH 15: training on 7700 raw words (2386 effective words) took 0.0s, 686904 effective words/s
# INFO - 2023-11-28 01:35:43,198: EPOCH 16: training on 7700 raw words (2432 effective words) took 0.0s, 400866 effective words/s
# INFO - 2023-11-28 01:35:43,208: EPOCH 17: training on 7700 raw words (2474 effective words) took 0.0s, 420806 effective words/s
# INFO - 2023-11-28 01:35:43,242: EPOCH 18: training on 7700 raw words (2375 effective words) took 0.0s, 79653 effective words/s
# INFO - 2023-11-28 01:35:43,250: EPOCH 19: training on 7700 raw words (2470 effective words) took 0.0s, 548702 effective words/s
# INFO - 2023-11-28 01:35:43,258: EPOCH 20: training on 7700 raw words (2407 effective words) took 0.0s, 523531 effective words/s
# INFO - 2023-11-28 01:35:43,267: EPOCH 21: training on 7700 raw words (2384 effective words) took 0.0s, 536755 effective words/s
# INFO - 2023-11-28 01:35:43,310: EPOCH 22: training on 7700 raw words (2422 effective words) took 0.0s, 472091 effective words/s
# INFO - 2023-11-28 01:35:43,318: EPOCH 23: training on 7700 raw words (2468 effective words) took 0.0s, 477950 effective words/s
# INFO - 2023-11-28 01:35:43,386: EPOCH 24: training on 7700 raw words (2413 effective words) took 0.0s, 500568 effective words/s
# INFO - 2023-11-28 01:35:43,433: EPOCH 25: training on 7700 raw words (2448 effective words) took 0.0s, 529028 effective words/s
# INFO - 2023-11-28 01:35:43,474: EPOCH 26: training on 7700 raw words (2335 effective words) took 0.0s, 442228 effective words/s
# INFO - 2023-11-28 01:35:43,482: EPOCH 27: training on 7700 raw words (2421 effective words) took 0.0s, 514544 effective words/s
# INFO - 2023-11-28 01:35:43,490: EPOCH 28: training on 7700 raw words (2388 effective words) took 0.0s, 513879 effective words/s
# INFO - 2023-11-28 01:35:43,535: EPOCH 29: training on 7700 raw words (2457 effective words) took 0.0s, 546203 effective words/s
# INFO - 2023-11-28 01:35:43,542: EPOCH 30: training on 7700 raw words (2432 effective words) took 0.0s, 541578 effective words/s
# INFO - 2023-11-28 01:35:43,577: EPOCH 31: training on 7700 raw words (2422 effective words) took 0.0s, 432492 effective words/s
# INFO - 2023-11-28 01:35:43,728: EPOCH 32: training on 7700 raw words (2404 effective words) took 0.0s, 503190 effective words/s
# INFO - 2023-11-28 01:35:43,748: EPOCH 33: training on 7700 raw words (2383 effective words) took 0.0s, 456959 effective words/s
# INFO - 2023-11-28 01:35:43,756: EPOCH 34: training on 7700 raw words (2440 effective words) took 0.0s, 572606 effective words/s
# INFO - 2023-11-28 01:35:43,818: EPOCH 35: training on 7700 raw words (2442 effective words) took 0.0s, 553872 effective words/s
# INFO - 2023-11-28 01:35:43,882: EPOCH 36: training on 7700 raw words (2377 effective words) took 0.0s, 460513 effective words/s
# INFO - 2023-11-28 01:35:43,890: EPOCH 37: training on 7700 raw words (2448 effective words) took 0.0s, 540650 effective words/s
# INFO - 2023-11-28 01:35:43,899: EPOCH 38: training on 7700 raw words (2346 effective words) took 0.0s, 484878 effective words/s
# INFO - 2023-11-28 01:35:43,908: EPOCH 39: training on 7700 raw words (2346 effective words) took 0.0s, 452416 effective words/s
# INFO - 2023-11-28 01:35:43,916: EPOCH 40: training on 7700 raw words (2428 effective words) took 0.0s, 477367 effective words/s
# INFO - 2023-11-28 01:35:43,924: EPOCH 41: training on 7700 raw words (2382 effective words) took 0.0s, 518027 effective words/s
# INFO - 2023-11-28 01:35:43,960: EPOCH 42: training on 7700 raw words (2433 effective words) took 0.0s, 75164 effective words/s
# INFO - 2023-11-28 01:35:43,968: EPOCH 43: training on 7700 raw words (2431 effective words) took 0.0s, 502336 effective words/s
# INFO - 2023-11-28 01:35:43,976: EPOCH 44: training on 7700 raw words (2385 effective words) took 0.0s, 461559 effective words/s
# INFO - 2023-11-28 01:35:43,984: EPOCH 45: training on 7700 raw words (2399 effective words) took 0.0s, 487420 effective words/s
# INFO - 2023-11-28 01:35:43,993: EPOCH 46: training on 7700 raw words (2379 effective words) took 0.0s, 478132 effective words/s
# INFO - 2023-11-28 01:35:44,001: EPOCH 47: training on 7700 raw words (2405 effective words) took 0.0s, 511950 effective words/s
# INFO - 2023-11-28 01:35:44,009: EPOCH 48: training on 7700 raw words (2428 effective words) took 0.0s, 472386 effective words/s
# INFO - 2023-11-28 01:35:44,018: EPOCH 49: training on 7700 raw words (2397 effective words) took 0.0s, 477680 effective words/s
# INFO - 2023-11-28 01:35:44,019: Word2Vec lifecycle event {'msg': 'training on 385000 raw words (120726 effective words) took 1.0s, 124112 effective words/s', 'datetime': '2023-11-28T01:35:44.019193', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:44,019: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:35:44.019721', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:35:44,411: collecting all words and their counts
# INFO - 2023-11-28 01:35:44,412: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:35:44,413: collected 77 word types from a corpus of 7700 raw words and 770 sentences
# INFO - 2023-11-28 01:35:44,414: Creating a fresh vocabulary
# INFO - 2023-11-28 01:35:44,414: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:35:44.414772', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:44,415: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 7700 word corpus (100.00% of original 7700, drops 0)', 'datetime': '2023-11-28T01:35:44.415311', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:44,416: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:35:44,417: sample=0.001 downsamples 58 most-common words
# INFO - 2023-11-28 01:35:44,417: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2386.975687330373 word corpus (31.0%% of prior 7700)', 'datetime': '2023-11-28T01:35:44.417733', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:44,419: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:35:44,419: resetting layer weights
# INFO - 2023-11-28 01:35:44,420: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:35:44.420510', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:35:44,421: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:35:44.421257', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:44,432: EPOCH 0: training on 7700 raw words (2351 effective words) took 0.0s, 523317 effective words/s
# INFO - 2023-11-28 01:35:44,440: EPOCH 1: training on 7700 raw words (2386 effective words) took 0.0s, 489451 effective words/s
# INFO - 2023-11-28 01:35:44,449: EPOCH 2: training on 7700 raw words (2392 effective words) took 0.0s, 511418 effective words/s
# INFO - 2023-11-28 01:35:44,457: EPOCH 3: training on 7700 raw words (2379 effective words) took 0.0s, 485800 effective words/s
# INFO - 2023-11-28 01:35:44,466: EPOCH 4: training on 7700 raw words (2370 effective words) took 0.0s, 533059 effective words/s
# INFO - 2023-11-28 01:35:44,474: EPOCH 5: training on 7700 raw words (2408 effective words) took 0.0s, 492797 effective words/s
# INFO - 2023-11-28 01:35:44,483: EPOCH 6: training on 7700 raw words (2420 effective words) took 0.0s, 489158 effective words/s
# INFO - 2023-11-28 01:35:44,531: EPOCH 7: training on 7700 raw words (2384 effective words) took 0.0s, 54292 effective words/s
# INFO - 2023-11-28 01:35:44,538: EPOCH 8: training on 7700 raw words (2318 effective words) took 0.0s, 497541 effective words/s
# INFO - 2023-11-28 01:35:44,548: EPOCH 9: training on 7700 raw words (2397 effective words) took 0.0s, 448967 effective words/s
# INFO - 2023-11-28 01:35:44,556: EPOCH 10: training on 7700 raw words (2382 effective words) took 0.0s, 515611 effective words/s
# INFO - 2023-11-28 01:35:44,565: EPOCH 11: training on 7700 raw words (2384 effective words) took 0.0s, 469325 effective words/s
# INFO - 2023-11-28 01:35:44,573: EPOCH 12: training on 7700 raw words (2369 effective words) took 0.0s, 473017 effective words/s
# INFO - 2023-11-28 01:35:44,610: EPOCH 13: training on 7700 raw words (2415 effective words) took 0.0s, 472976 effective words/s
# INFO - 2023-11-28 01:35:44,619: EPOCH 14: training on 7700 raw words (2373 effective words) took 0.0s, 517475 effective words/s
# INFO - 2023-11-28 01:35:44,811: EPOCH 15: training on 7700 raw words (2376 effective words) took 0.0s, 371979 effective words/s
# INFO - 2023-11-28 01:35:44,821: EPOCH 16: training on 7700 raw words (2372 effective words) took 0.0s, 514213 effective words/s
# INFO - 2023-11-28 01:35:44,849: EPOCH 17: training on 7700 raw words (2388 effective words) took 0.0s, 98888 effective words/s
# INFO - 2023-11-28 01:35:44,968: EPOCH 18: training on 7700 raw words (2428 effective words) took 0.0s, 526672 effective words/s
# INFO - 2023-11-28 01:35:44,975: EPOCH 19: training on 7700 raw words (2305 effective words) took 0.0s, 495664 effective words/s
# INFO - 2023-11-28 01:35:44,983: EPOCH 20: training on 7700 raw words (2369 effective words) took 0.0s, 469262 effective words/s
# INFO - 2023-11-28 01:35:45,221: EPOCH 21: training on 7700 raw words (2394 effective words) took 0.2s, 10211 effective words/s
# INFO - 2023-11-28 01:35:45,229: EPOCH 22: training on 7700 raw words (2399 effective words) took 0.0s, 525200 effective words/s
# INFO - 2023-11-28 01:35:45,237: EPOCH 23: training on 7700 raw words (2446 effective words) took 0.0s, 497485 effective words/s
# INFO - 2023-11-28 01:35:45,246: EPOCH 24: training on 7700 raw words (2355 effective words) took 0.0s, 524890 effective words/s
# INFO - 2023-11-28 01:35:45,254: EPOCH 25: training on 7700 raw words (2410 effective words) took 0.0s, 464819 effective words/s
# INFO - 2023-11-28 01:35:45,262: EPOCH 26: training on 7700 raw words (2365 effective words) took 0.0s, 485974 effective words/s
# INFO - 2023-11-28 01:35:45,270: EPOCH 27: training on 7700 raw words (2367 effective words) took 0.0s, 550150 effective words/s
# INFO - 2023-11-28 01:35:45,279: EPOCH 28: training on 7700 raw words (2454 effective words) took 0.0s, 506011 effective words/s
# INFO - 2023-11-28 01:35:45,287: EPOCH 29: training on 7700 raw words (2394 effective words) took 0.0s, 497613 effective words/s
# INFO - 2023-11-28 01:35:45,294: EPOCH 30: training on 7700 raw words (2399 effective words) took 0.0s, 514126 effective words/s
# INFO - 2023-11-28 01:35:45,303: EPOCH 31: training on 7700 raw words (2403 effective words) took 0.0s, 497250 effective words/s
# INFO - 2023-11-28 01:35:45,433: EPOCH 32: training on 7700 raw words (2398 effective words) took 0.1s, 44889 effective words/s
# INFO - 2023-11-28 01:35:45,503: EPOCH 33: training on 7700 raw words (2331 effective words) took 0.0s, 390476 effective words/s
# INFO - 2023-11-28 01:35:45,513: EPOCH 34: training on 7700 raw words (2409 effective words) took 0.0s, 452502 effective words/s
# INFO - 2023-11-28 01:35:45,536: EPOCH 35: training on 7700 raw words (2394 effective words) took 0.0s, 487710 effective words/s
# INFO - 2023-11-28 01:35:45,570: EPOCH 36: training on 7700 raw words (2442 effective words) took 0.0s, 498870 effective words/s
# INFO - 2023-11-28 01:35:45,691: EPOCH 37: training on 7700 raw words (2423 effective words) took 0.0s, 375819 effective words/s
# INFO - 2023-11-28 01:35:45,956: EPOCH 38: training on 7700 raw words (2360 effective words) took 0.0s, 374575 effective words/s
# INFO - 2023-11-28 01:35:46,146: EPOCH 39: training on 7700 raw words (2395 effective words) took 0.0s, 377443 effective words/s
# INFO - 2023-11-28 01:35:46,155: EPOCH 40: training on 7700 raw words (2321 effective words) took 0.0s, 483455 effective words/s
# INFO - 2023-11-28 01:35:46,165: EPOCH 41: training on 7700 raw words (2399 effective words) took 0.0s, 377474 effective words/s
# INFO - 2023-11-28 01:35:46,172: EPOCH 42: training on 7700 raw words (2360 effective words) took 0.0s, 545174 effective words/s
# INFO - 2023-11-28 01:35:46,180: EPOCH 43: training on 7700 raw words (2403 effective words) took 0.0s, 509740 effective words/s
# INFO - 2023-11-28 01:35:46,188: EPOCH 44: training on 7700 raw words (2368 effective words) took 0.0s, 518381 effective words/s
# INFO - 2023-11-28 01:35:46,196: EPOCH 45: training on 7700 raw words (2323 effective words) took 0.0s, 456855 effective words/s
# INFO - 2023-11-28 01:35:46,204: EPOCH 46: training on 7700 raw words (2281 effective words) took 0.0s, 492230 effective words/s
# INFO - 2023-11-28 01:35:46,212: EPOCH 47: training on 7700 raw words (2403 effective words) took 0.0s, 475389 effective words/s
# INFO - 2023-11-28 01:35:46,220: EPOCH 48: training on 7700 raw words (2456 effective words) took 0.0s, 540933 effective words/s
# INFO - 2023-11-28 01:35:46,299: EPOCH 49: training on 7700 raw words (2353 effective words) took 0.0s, 549040 effective words/s
# INFO - 2023-11-28 01:35:46,300: Word2Vec lifecycle event {'msg': 'training on 385000 raw words (119171 effective words) took 1.9s, 63427 effective words/s', 'datetime': '2023-11-28T01:35:46.300861', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:46,301: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:35:46.301701', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:35:46,775: collecting all words and their counts
# INFO - 2023-11-28 01:35:46,776: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:35:46,777: collected 77 word types from a corpus of 7700 raw words and 770 sentences
# INFO - 2023-11-28 01:35:46,778: Creating a fresh vocabulary
# INFO - 2023-11-28 01:35:46,779: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:35:46.779400', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:46,780: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 7700 word corpus (100.00% of original 7700, drops 0)', 'datetime': '2023-11-28T01:35:46.780092', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:46,781: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:35:46,781: sample=0.001 downsamples 62 most-common words
# INFO - 2023-11-28 01:35:46,782: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2436.9749735157825 word corpus (31.6%% of prior 7700)', 'datetime': '2023-11-28T01:35:46.782488', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:46,784: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:35:46,784: resetting layer weights
# INFO - 2023-11-28 01:35:46,785: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:35:46.785797', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:35:46,786: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:35:46.786526', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:46,798: EPOCH 0: training on 7700 raw words (2384 effective words) took 0.0s, 509985 effective words/s
# INFO - 2023-11-28 01:35:46,855: EPOCH 1: training on 7700 raw words (2489 effective words) took 0.0s, 400469 effective words/s
# INFO - 2023-11-28 01:35:46,901: EPOCH 2: training on 7700 raw words (2398 effective words) took 0.0s, 54751 effective words/s
# INFO - 2023-11-28 01:35:46,937: EPOCH 3: training on 7700 raw words (2484 effective words) took 0.0s, 675630 effective words/s
# INFO - 2023-11-28 01:35:46,946: EPOCH 4: training on 7700 raw words (2478 effective words) took 0.0s, 484591 effective words/s
# INFO - 2023-11-28 01:35:46,955: EPOCH 5: training on 7700 raw words (2501 effective words) took 0.0s, 485205 effective words/s
# INFO - 2023-11-28 01:35:46,964: EPOCH 6: training on 7700 raw words (2399 effective words) took 0.0s, 497679 effective words/s
# INFO - 2023-11-28 01:35:46,972: EPOCH 7: training on 7700 raw words (2458 effective words) took 0.0s, 468115 effective words/s
# INFO - 2023-11-28 01:35:46,980: EPOCH 8: training on 7700 raw words (2420 effective words) took 0.0s, 496413 effective words/s
# INFO - 2023-11-28 01:35:46,988: EPOCH 9: training on 7700 raw words (2511 effective words) took 0.0s, 485375 effective words/s
# INFO - 2023-11-28 01:35:46,997: EPOCH 10: training on 7700 raw words (2421 effective words) took 0.0s, 442643 effective words/s
# INFO - 2023-11-28 01:35:47,006: EPOCH 11: training on 7700 raw words (2386 effective words) took 0.0s, 432691 effective words/s
# INFO - 2023-11-28 01:35:47,014: EPOCH 12: training on 7700 raw words (2404 effective words) took 0.0s, 499647 effective words/s
# INFO - 2023-11-28 01:35:47,034: EPOCH 13: training on 7700 raw words (2512 effective words) took 0.0s, 506878 effective words/s
# INFO - 2023-11-28 01:35:47,043: EPOCH 14: training on 7700 raw words (2431 effective words) took 0.0s, 428796 effective words/s
# INFO - 2023-11-28 01:35:47,051: EPOCH 15: training on 7700 raw words (2429 effective words) took 0.0s, 496266 effective words/s
# INFO - 2023-11-28 01:35:47,060: EPOCH 16: training on 7700 raw words (2420 effective words) took 0.0s, 442372 effective words/s
# INFO - 2023-11-28 01:35:47,069: EPOCH 17: training on 7700 raw words (2467 effective words) took 0.0s, 459620 effective words/s
# INFO - 2023-11-28 01:35:47,077: EPOCH 18: training on 7700 raw words (2404 effective words) took 0.0s, 510923 effective words/s
# INFO - 2023-11-28 01:35:47,085: EPOCH 19: training on 7700 raw words (2380 effective words) took 0.0s, 480692 effective words/s
# INFO - 2023-11-28 01:35:47,093: EPOCH 20: training on 7700 raw words (2434 effective words) took 0.0s, 477126 effective words/s
# INFO - 2023-11-28 01:35:47,102: EPOCH 21: training on 7700 raw words (2466 effective words) took 0.0s, 484015 effective words/s
# INFO - 2023-11-28 01:35:47,110: EPOCH 22: training on 7700 raw words (2377 effective words) took 0.0s, 529202 effective words/s
# INFO - 2023-11-28 01:35:47,117: EPOCH 23: training on 7700 raw words (2441 effective words) took 0.0s, 530899 effective words/s
# INFO - 2023-11-28 01:35:47,125: EPOCH 24: training on 7700 raw words (2390 effective words) took 0.0s, 512101 effective words/s
# INFO - 2023-11-28 01:35:47,135: EPOCH 25: training on 7700 raw words (2525 effective words) took 0.0s, 447137 effective words/s
# INFO - 2023-11-28 01:35:47,173: EPOCH 26: training on 7700 raw words (2536 effective words) took 0.0s, 503881 effective words/s
# INFO - 2023-11-28 01:35:47,181: EPOCH 27: training on 7700 raw words (2471 effective words) took 0.0s, 500727 effective words/s
# INFO - 2023-11-28 01:35:47,188: EPOCH 28: training on 7700 raw words (2451 effective words) took 0.0s, 516690 effective words/s
# INFO - 2023-11-28 01:35:47,197: EPOCH 29: training on 7700 raw words (2479 effective words) took 0.0s, 612099 effective words/s
# INFO - 2023-11-28 01:35:47,444: EPOCH 30: training on 7700 raw words (2443 effective words) took 0.2s, 15488 effective words/s
# INFO - 2023-11-28 01:35:47,454: EPOCH 31: training on 7700 raw words (2414 effective words) took 0.0s, 439360 effective words/s
# INFO - 2023-11-28 01:35:47,464: EPOCH 32: training on 7700 raw words (2390 effective words) took 0.0s, 367109 effective words/s
# INFO - 2023-11-28 01:35:47,617: EPOCH 33: training on 7700 raw words (2419 effective words) took 0.0s, 428316 effective words/s
# INFO - 2023-11-28 01:35:47,694: EPOCH 34: training on 7700 raw words (2400 effective words) took 0.0s, 449367 effective words/s
# INFO - 2023-11-28 01:35:47,704: EPOCH 35: training on 7700 raw words (2441 effective words) took 0.0s, 422097 effective words/s
# INFO - 2023-11-28 01:35:47,712: EPOCH 36: training on 7700 raw words (2433 effective words) took 0.0s, 456315 effective words/s
# INFO - 2023-11-28 01:35:47,721: EPOCH 37: training on 7700 raw words (2461 effective words) took 0.0s, 437403 effective words/s
# INFO - 2023-11-28 01:35:47,730: EPOCH 38: training on 7700 raw words (2420 effective words) took 0.0s, 477118 effective words/s
# INFO - 2023-11-28 01:35:47,739: EPOCH 39: training on 7700 raw words (2461 effective words) took 0.0s, 466707 effective words/s
# INFO - 2023-11-28 01:35:47,749: EPOCH 40: training on 7700 raw words (2404 effective words) took 0.0s, 450668 effective words/s
# INFO - 2023-11-28 01:35:47,758: EPOCH 41: training on 7700 raw words (2418 effective words) took 0.0s, 426163 effective words/s
# INFO - 2023-11-28 01:35:47,767: EPOCH 42: training on 7700 raw words (2432 effective words) took 0.0s, 525825 effective words/s
# INFO - 2023-11-28 01:35:47,775: EPOCH 43: training on 7700 raw words (2420 effective words) took 0.0s, 496890 effective words/s
# INFO - 2023-11-28 01:35:47,784: EPOCH 44: training on 7700 raw words (2489 effective words) took 0.0s, 482346 effective words/s
# INFO - 2023-11-28 01:35:47,793: EPOCH 45: training on 7700 raw words (2485 effective words) took 0.0s, 476535 effective words/s
# INFO - 2023-11-28 01:35:47,801: EPOCH 46: training on 7700 raw words (2442 effective words) took 0.0s, 492944 effective words/s
# INFO - 2023-11-28 01:35:47,810: EPOCH 47: training on 7700 raw words (2385 effective words) took 0.0s, 491931 effective words/s
# INFO - 2023-11-28 01:35:47,818: EPOCH 48: training on 7700 raw words (2429 effective words) took 0.0s, 486764 effective words/s
# INFO - 2023-11-28 01:35:47,828: EPOCH 49: training on 7700 raw words (2379 effective words) took 0.0s, 405968 effective words/s
# INFO - 2023-11-28 01:35:47,829: Word2Vec lifecycle event {'msg': 'training on 385000 raw words (121911 effective words) took 1.0s, 116999 effective words/s', 'datetime': '2023-11-28T01:35:47.829177', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:47,829: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:35:47.829873', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:35:48,280: collecting all words and their counts
# INFO - 2023-11-28 01:35:48,281: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:35:48,282: collected 77 word types from a corpus of 7700 raw words and 770 sentences
# INFO - 2023-11-28 01:35:48,283: Creating a fresh vocabulary
# INFO - 2023-11-28 01:35:48,284: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:35:48.283981', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:48,284: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 7700 word corpus (100.00% of original 7700, drops 0)', 'datetime': '2023-11-28T01:35:48.284496', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:48,285: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:35:48,286: sample=0.001 downsamples 59 most-common words
# INFO - 2023-11-28 01:35:48,286: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2407.9084705116907 word corpus (31.3%% of prior 7700)', 'datetime': '2023-11-28T01:35:48.286797', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:48,289: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:35:48,290: resetting layer weights
# INFO - 2023-11-28 01:35:48,293: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:35:48.293681', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:35:48,294: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:35:48.294359', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:48,365: EPOCH 0: training on 7700 raw words (2357 effective words) took 0.1s, 35336 effective words/s
# INFO - 2023-11-28 01:35:48,373: EPOCH 1: training on 7700 raw words (2358 effective words) took 0.0s, 535702 effective words/s
# INFO - 2023-11-28 01:35:48,394: EPOCH 2: training on 7700 raw words (2409 effective words) took 0.0s, 545610 effective words/s
# INFO - 2023-11-28 01:35:48,402: EPOCH 3: training on 7700 raw words (2379 effective words) took 0.0s, 501400 effective words/s
# INFO - 2023-11-28 01:35:48,422: EPOCH 4: training on 7700 raw words (2366 effective words) took 0.0s, 497648 effective words/s
# INFO - 2023-11-28 01:35:48,430: EPOCH 5: training on 7700 raw words (2343 effective words) took 0.0s, 526877 effective words/s
# INFO - 2023-11-28 01:35:48,438: EPOCH 6: training on 7700 raw words (2396 effective words) took 0.0s, 467914 effective words/s
# INFO - 2023-11-28 01:35:48,447: EPOCH 7: training on 7700 raw words (2490 effective words) took 0.0s, 495729 effective words/s
# INFO - 2023-11-28 01:35:48,456: EPOCH 8: training on 7700 raw words (2381 effective words) took 0.0s, 463821 effective words/s
# INFO - 2023-11-28 01:35:48,464: EPOCH 9: training on 7700 raw words (2390 effective words) took 0.0s, 504926 effective words/s
# INFO - 2023-11-28 01:35:48,472: EPOCH 10: training on 7700 raw words (2369 effective words) took 0.0s, 492963 effective words/s
# INFO - 2023-11-28 01:35:48,480: EPOCH 11: training on 7700 raw words (2410 effective words) took 0.0s, 504609 effective words/s
# INFO - 2023-11-28 01:35:48,488: EPOCH 12: training on 7700 raw words (2474 effective words) took 0.0s, 520538 effective words/s
# INFO - 2023-11-28 01:35:48,497: EPOCH 13: training on 7700 raw words (2420 effective words) took 0.0s, 559923 effective words/s
# INFO - 2023-11-28 01:35:48,505: EPOCH 14: training on 7700 raw words (2386 effective words) took 0.0s, 488290 effective words/s
# INFO - 2023-11-28 01:35:48,513: EPOCH 15: training on 7700 raw words (2367 effective words) took 0.0s, 496180 effective words/s
# INFO - 2023-11-28 01:35:48,521: EPOCH 16: training on 7700 raw words (2378 effective words) took 0.0s, 514587 effective words/s
# INFO - 2023-11-28 01:35:48,529: EPOCH 17: training on 7700 raw words (2433 effective words) took 0.0s, 529082 effective words/s
# INFO - 2023-11-28 01:35:48,537: EPOCH 18: training on 7700 raw words (2427 effective words) took 0.0s, 547736 effective words/s
# INFO - 2023-11-28 01:35:48,545: EPOCH 19: training on 7700 raw words (2389 effective words) took 0.0s, 523855 effective words/s
# INFO - 2023-11-28 01:35:48,553: EPOCH 20: training on 7700 raw words (2407 effective words) took 0.0s, 479219 effective words/s
# INFO - 2023-11-28 01:35:48,561: EPOCH 21: training on 7700 raw words (2446 effective words) took 0.0s, 458444 effective words/s
# INFO - 2023-11-28 01:35:48,569: EPOCH 22: training on 7700 raw words (2408 effective words) took 0.0s, 488887 effective words/s
# INFO - 2023-11-28 01:35:48,593: EPOCH 23: training on 7700 raw words (2399 effective words) took 0.0s, 494698 effective words/s
# INFO - 2023-11-28 01:35:48,601: EPOCH 24: training on 7700 raw words (2403 effective words) took 0.0s, 529945 effective words/s
# INFO - 2023-11-28 01:35:48,609: EPOCH 25: training on 7700 raw words (2413 effective words) took 0.0s, 476186 effective words/s
# INFO - 2023-11-28 01:35:48,617: EPOCH 26: training on 7700 raw words (2452 effective words) took 0.0s, 521817 effective words/s
# INFO - 2023-11-28 01:35:48,625: EPOCH 27: training on 7700 raw words (2368 effective words) took 0.0s, 497917 effective words/s
# INFO - 2023-11-28 01:35:48,641: EPOCH 28: training on 7700 raw words (2439 effective words) took 0.0s, 511579 effective words/s
# INFO - 2023-11-28 01:35:48,716: EPOCH 29: training on 7700 raw words (2432 effective words) took 0.0s, 376784 effective words/s
# INFO - 2023-11-28 01:35:48,747: EPOCH 30: training on 7700 raw words (2432 effective words) took 0.0s, 556453 effective words/s
# INFO - 2023-11-28 01:35:48,767: EPOCH 31: training on 7700 raw words (2379 effective words) took 0.0s, 397797 effective words/s
# INFO - 2023-11-28 01:35:48,776: EPOCH 32: training on 7700 raw words (2373 effective words) took 0.0s, 425920 effective words/s
# INFO - 2023-11-28 01:35:48,785: EPOCH 33: training on 7700 raw words (2397 effective words) took 0.0s, 422379 effective words/s
# INFO - 2023-11-28 01:35:48,797: EPOCH 34: training on 7700 raw words (2413 effective words) took 0.0s, 336018 effective words/s
# INFO - 2023-11-28 01:35:48,806: EPOCH 35: training on 7700 raw words (2409 effective words) took 0.0s, 476916 effective words/s
# INFO - 2023-11-28 01:35:48,814: EPOCH 36: training on 7700 raw words (2480 effective words) took 0.0s, 485709 effective words/s
# INFO - 2023-11-28 01:35:48,822: EPOCH 37: training on 7700 raw words (2420 effective words) took 0.0s, 547137 effective words/s
# INFO - 2023-11-28 01:35:48,831: EPOCH 38: training on 7700 raw words (2427 effective words) took 0.0s, 504802 effective words/s
# INFO - 2023-11-28 01:35:48,839: EPOCH 39: training on 7700 raw words (2417 effective words) took 0.0s, 502631 effective words/s
# INFO - 2023-11-28 01:35:48,847: EPOCH 40: training on 7700 raw words (2412 effective words) took 0.0s, 497180 effective words/s
# INFO - 2023-11-28 01:35:48,855: EPOCH 41: training on 7700 raw words (2418 effective words) took 0.0s, 554631 effective words/s
# INFO - 2023-11-28 01:35:48,864: EPOCH 42: training on 7700 raw words (2357 effective words) took 0.0s, 449688 effective words/s
# INFO - 2023-11-28 01:35:48,873: EPOCH 43: training on 7700 raw words (2448 effective words) took 0.0s, 439438 effective words/s
# INFO - 2023-11-28 01:35:48,883: EPOCH 44: training on 7700 raw words (2403 effective words) took 0.0s, 363749 effective words/s
# INFO - 2023-11-28 01:35:48,893: EPOCH 45: training on 7700 raw words (2405 effective words) took 0.0s, 399012 effective words/s
# INFO - 2023-11-28 01:35:48,901: EPOCH 46: training on 7700 raw words (2416 effective words) took 0.0s, 486362 effective words/s
# INFO - 2023-11-28 01:35:48,909: EPOCH 47: training on 7700 raw words (2410 effective words) took 0.0s, 526549 effective words/s
# INFO - 2023-11-28 01:35:48,917: EPOCH 48: training on 7700 raw words (2354 effective words) took 0.0s, 503755 effective words/s
# INFO - 2023-11-28 01:35:48,925: EPOCH 49: training on 7700 raw words (2415 effective words) took 0.0s, 525539 effective words/s
# INFO - 2023-11-28 01:35:48,926: Word2Vec lifecycle event {'msg': 'training on 385000 raw words (120274 effective words) took 0.6s, 190495 effective words/s', 'datetime': '2023-11-28T01:35:48.926353', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:48,927: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:35:48.926996', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:35:49,381: collecting all words and their counts
# INFO - 2023-11-28 01:35:49,381: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:35:49,383: collected 77 word types from a corpus of 7700 raw words and 770 sentences
# INFO - 2023-11-28 01:35:49,384: Creating a fresh vocabulary
# INFO - 2023-11-28 01:35:49,385: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:35:49.385009', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:49,385: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 7700 word corpus (100.00% of original 7700, drops 0)', 'datetime': '2023-11-28T01:35:49.385690', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:49,386: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:35:49,387: sample=0.001 downsamples 58 most-common words
# INFO - 2023-11-28 01:35:49,388: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2402.192733510968 word corpus (31.2%% of prior 7700)', 'datetime': '2023-11-28T01:35:49.388614', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:35:49,390: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:35:49,390: resetting layer weights
# INFO - 2023-11-28 01:35:49,394: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:35:49.394097', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:35:49,395: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:35:49.395132', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:35:49,403: EPOCH 0: training on 7700 raw words (2351 effective words) took 0.0s, 504253 effective words/s
# INFO - 2023-11-28 01:35:49,425: EPOCH 1: training on 7700 raw words (2393 effective words) took 0.0s, 127756 effective words/s
# INFO - 2023-11-28 01:35:49,453: EPOCH 2: training on 7700 raw words (2435 effective words) took 0.0s, 99777 effective words/s
# INFO - 2023-11-28 01:35:49,461: EPOCH 3: training on 7700 raw words (2355 effective words) took 0.0s, 434827 effective words/s
# INFO - 2023-11-28 01:35:49,470: EPOCH 4: training on 7700 raw words (2439 effective words) took 0.0s, 475564 effective words/s
# INFO - 2023-11-28 01:35:49,478: EPOCH 5: training on 7700 raw words (2452 effective words) took 0.0s, 501344 effective words/s
# INFO - 2023-11-28 01:35:49,486: EPOCH 6: training on 7700 raw words (2442 effective words) took 0.0s, 512186 effective words/s
# INFO - 2023-11-28 01:35:49,494: EPOCH 7: training on 7700 raw words (2366 effective words) took 0.0s, 498703 effective words/s
# INFO - 2023-11-28 01:35:49,503: EPOCH 8: training on 7700 raw words (2408 effective words) took 0.0s, 461587 effective words/s
# INFO - 2023-11-28 01:35:49,511: EPOCH 9: training on 7700 raw words (2450 effective words) took 0.0s, 464342 effective words/s
# INFO - 2023-11-28 01:35:49,519: EPOCH 10: training on 7700 raw words (2393 effective words) took 0.0s, 495241 effective words/s
# INFO - 2023-11-28 01:35:49,528: EPOCH 11: training on 7700 raw words (2433 effective words) took 0.0s, 488578 effective words/s
# INFO - 2023-11-28 01:35:49,537: EPOCH 12: training on 7700 raw words (2426 effective words) took 0.0s, 482168 effective words/s
# INFO - 2023-11-28 01:35:49,603: EPOCH 13: training on 7700 raw words (2386 effective words) took 0.0s, 61664 effective words/s
# INFO - 2023-11-28 01:35:49,611: EPOCH 14: training on 7700 raw words (2427 effective words) took 0.0s, 441659 effective words/s
# INFO - 2023-11-28 01:35:49,620: EPOCH 15: training on 7700 raw words (2450 effective words) took 0.0s, 547047 effective words/s
# INFO - 2023-11-28 01:35:49,629: EPOCH 16: training on 7700 raw words (2398 effective words) took 0.0s, 453478 effective words/s
# INFO - 2023-11-28 01:35:49,664: EPOCH 17: training on 7700 raw words (2370 effective words) took 0.0s, 481972 effective words/s
# INFO - 2023-11-28 01:35:49,773: EPOCH 18: training on 7700 raw words (2371 effective words) took 0.0s, 451902 effective words/s
# INFO - 2023-11-28 01:35:49,868: EPOCH 19: training on 7700 raw words (2381 effective words) took 0.1s, 26376 effective words/s
# INFO - 2023-11-28 01:35:49,950: EPOCH 20: training on 7700 raw words (2411 effective words) took 0.0s, 375440 effective words/s
# INFO - 2023-11-28 01:35:49,958: EPOCH 21: training on 7700 raw words (2359 effective words) took 0.0s, 525812 effective words/s
# INFO - 2023-11-28 01:35:49,967: EPOCH 22: training on 7700 raw words (2438 effective words) took 0.0s, 476618 effective words/s
# INFO - 2023-11-28 01:35:49,976: EPOCH 23: training on 7700 raw words (2351 effective words) took 0.0s, 472212 effective words/s
# INFO - 2023-11-28 01:35:49,985: EPOCH 24: training on 7700 raw words (2350 effective words) took 0.0s, 491075 effective words/s
# INFO - 2023-11-28 01:35:49,994: EPOCH 25: training on 7700 raw words (2358 effective words) took 0.0s, 464486 effective words/s
# INFO - 2023-11-28 01:35:50,003: EPOCH 26: training on 7700 raw words (2419 effective words) took 0.0s, 447559 effective words/s
# INFO - 2023-11-28 01:35:50,012: EPOCH 27: training on 7700 raw words (2316 effective words) took 0.0s, 478280 effective words/s
# INFO - 2023-11-28 01:35:50,020: EPOCH 28: training on 7700 raw words (2440 effective words) took 0.0s, 487101 effective words/s
# INFO - 2023-11-28 01:35:50,031: EPOCH 29: training on 7700 raw words (2445 effective words) took 0.0s, 403579 effective words/s
# INFO - 2023-11-28 01:35:50,039: EPOCH 30: training on 7700 raw words (2358 effective words) took 0.0s, 447354 effective words/s
# INFO - 2023-11-28 01:35:50,048: EPOCH 31: training on 7700 raw words (2384 effective words) took 0.0s, 483037 effective words/s
# INFO - 2023-11-28 01:35:50,056: EPOCH 32: training on 7700 raw words (2344 effective words) took 0.0s, 523075 effective words/s
# INFO - 2023-11-28 01:35:50,066: EPOCH 33: training on 7700 raw words (2336 effective words) took 0.0s, 478591 effective words/s
# INFO - 2023-11-28 01:35:50,075: EPOCH 34: training on 7700 raw words (2496 effective words) took 0.0s, 423704 effective words/s
# INFO - 2023-11-28 01:35:50,083: EPOCH 35: training on 7700 raw words (2350 effective words) took 0.0s, 529327 effective words/s
# INFO - 2023-11-28 01:35:50,092: EPOCH 36: training on 7700 raw words (2414 effective words) took 0.0s, 540892 effective words/s
# INFO - 2023-11-28 01:35:50,101: EPOCH 37: training on 7700 raw words (2450 effective words) took 0.0s, 422326 effective words/s
# INFO - 2023-11-28 01:35:50,110: EPOCH 38: training on 7700 raw words (2454 effective words) took 0.0s, 432470 effective words/s
# INFO - 2023-11-28 01:35:50,119: EPOCH 39: training on 7700 raw words (2451 effective words) took 0.0s, 447642 effective words/s
# ...
# INFO - 2023-11-28 01:39:39,995: EPOCH 13: training on 7700 raw words (2395 effective words) took 0.0s, 351777 effective words/s
# INFO - 2023-11-28 01:39:40,006: EPOCH 14: training on 7700 raw words (2397 effective words) took 0.0s, 346113 effective words/s
# INFO - 2023-11-28 01:39:40,014: EPOCH 15: training on 7700 raw words (2430 effective words) took 0.0s, 483802 effective words/s
# INFO - 2023-11-28 01:39:40,025: EPOCH 16: training on 7700 raw words (2429 effective words) took 0.0s, 400035 effective words/s
# INFO - 2023-11-28 01:39:40,034: EPOCH 17: training on 7700 raw words (2428 effective words) took 0.0s, 411132 effective words/s
# INFO - 2023-11-28 01:39:40,045: EPOCH 18: training on 7700 raw words (2351 effective words) took 0.0s, 351789 effective words/s
# INFO - 2023-11-28 01:39:40,056: EPOCH 19: training on 7700 raw words (2338 effective words) took 0.0s, 356757 effective words/s
# INFO - 2023-11-28 01:39:40,067: EPOCH 20: training on 7700 raw words (2427 effective words) took 0.0s, 407121 effective words/s
# INFO - 2023-11-28 01:39:40,075: EPOCH 21: training on 7700 raw words (2387 effective words) took 0.0s, 470636 effective words/s
# INFO - 2023-11-28 01:39:40,085: EPOCH 22: training on 7700 raw words (2396 effective words) took 0.0s, 370313 effective words/s
# INFO - 2023-11-28 01:39:40,094: EPOCH 23: training on 7700 raw words (2389 effective words) took 0.0s, 467364 effective words/s
# INFO - 2023-11-28 01:39:40,103: EPOCH 24: training on 7700 raw words (2412 effective words) took 0.0s, 456395 effective words/s
# INFO - 2023-11-28 01:39:40,114: EPOCH 25: training on 7700 raw words (2414 effective words) took 0.0s, 359327 effective words/s
# INFO - 2023-11-28 01:39:40,124: EPOCH 26: training on 7700 raw words (2354 effective words) took 0.0s, 417540 effective words/s
# INFO - 2023-11-28 01:39:40,142: EPOCH 27: training on 7700 raw words (2374 effective words) took 0.0s, 210098 effective words/s
# INFO - 2023-11-28 01:39:40,154: EPOCH 28: training on 7700 raw words (2382 effective words) took 0.0s, 360108 effective words/s
# INFO - 2023-11-28 01:39:40,165: EPOCH 29: training on 7700 raw words (2396 effective words) took 0.0s, 388676 effective words/s
# INFO - 2023-11-28 01:39:40,176: EPOCH 30: training on 7700 raw words (2413 effective words) took 0.0s, 346518 effective words/s
# INFO - 2023-11-28 01:39:40,188: EPOCH 31: training on 7700 raw words (2368 effective words) took 0.0s, 383049 effective words/s
# INFO - 2023-11-28 01:39:40,198: EPOCH 32: training on 7700 raw words (2399 effective words) took 0.0s, 427629 effective words/s
# INFO - 2023-11-28 01:39:40,207: EPOCH 33: training on 7700 raw words (2416 effective words) took 0.0s, 491241 effective words/s
# INFO - 2023-11-28 01:39:40,216: EPOCH 34: training on 7700 raw words (2408 effective words) took 0.0s, 499832 effective words/s
# INFO - 2023-11-28 01:39:40,229: EPOCH 35: training on 7700 raw words (2493 effective words) took 0.0s, 284246 effective words/s
# INFO - 2023-11-28 01:39:40,239: EPOCH 36: training on 7700 raw words (2354 effective words) took 0.0s, 396639 effective words/s
# INFO - 2023-11-28 01:39:40,249: EPOCH 37: training on 7700 raw words (2405 effective words) took 0.0s, 476765 effective words/s
# INFO - 2023-11-28 01:39:40,260: EPOCH 38: training on 7700 raw words (2445 effective words) took 0.0s, 382681 effective words/s
# INFO - 2023-11-28 01:39:40,268: EPOCH 39: training on 7700 raw words (2448 effective words) took 0.0s, 522934 effective words/s
# INFO - 2023-11-28 01:39:40,277: EPOCH 40: training on 7700 raw words (2388 effective words) took 0.0s, 486324 effective words/s
# INFO - 2023-11-28 01:39:40,288: EPOCH 41: training on 7700 raw words (2452 effective words) took 0.0s, 372636 effective words/s
# INFO - 2023-11-28 01:39:40,297: EPOCH 42: training on 7700 raw words (2361 effective words) took 0.0s, 486594 effective words/s
# INFO - 2023-11-28 01:39:40,305: EPOCH 43: training on 7700 raw words (2431 effective words) took 0.0s, 462977 effective words/s
# INFO - 2023-11-28 01:39:40,313: EPOCH 44: training on 7700 raw words (2354 effective words) took 0.0s, 529783 effective words/s
# INFO - 2023-11-28 01:39:40,322: EPOCH 45: training on 7700 raw words (2363 effective words) took 0.0s, 508313 effective words/s
# INFO - 2023-11-28 01:39:40,332: EPOCH 46: training on 7700 raw words (2375 effective words) took 0.0s, 365290 effective words/s
# INFO - 2023-11-28 01:39:40,344: EPOCH 47: training on 7700 raw words (2408 effective words) took 0.0s, 356940 effective words/s
# INFO - 2023-11-28 01:39:40,355: EPOCH 48: training on 7700 raw words (2393 effective words) took 0.0s, 328002 effective words/s
# INFO - 2023-11-28 01:39:40,366: EPOCH 49: training on 7700 raw words (2426 effective words) took 0.0s, 399096 effective words/s
# INFO - 2023-11-28 01:39:40,367: Word2Vec lifecycle event {'msg': 'training on 385000 raw words (119963 effective words) took 0.5s, 226523 effective words/s', 'datetime': '2023-11-28T01:39:40.367861', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:39:40,368: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:39:40.368535', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# INFO - 2023-11-28 01:39:40,836: collecting all words and their counts
# INFO - 2023-11-28 01:39:40,837: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:39:40,838: collected 77 word types from a corpus of 7700 raw words and 770 sentences
# INFO - 2023-11-28 01:39:40,839: Creating a fresh vocabulary
# INFO - 2023-11-28 01:39:40,840: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:39:40.840762', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:39:40,842: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 7700 word corpus (100.00% of original 7700, drops 0)', 'datetime': '2023-11-28T01:39:40.842038', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:39:40,843: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:39:40,844: sample=0.001 downsamples 61 most-common words
# INFO - 2023-11-28 01:39:40,845: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2428.914706497969 word corpus (31.5%% of prior 7700)', 'datetime': '2023-11-28T01:39:40.845433', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:39:40,846: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-28 01:39:40,847: resetting layer weights
# INFO - 2023-11-28 01:39:40,847: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:39:40.847960', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:39:40,848: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2023-11-28T01:39:40.848900', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:39:40,860: EPOCH 0: training on 7700 raw words (2401 effective words) took 0.0s, 476707 effective words/s
# INFO - 2023-11-28 01:39:40,868: EPOCH 1: training on 7700 raw words (2384 effective words) took 0.0s, 508662 effective words/s
# INFO - 2023-11-28 01:39:40,877: EPOCH 2: training on 7700 raw words (2454 effective words) took 0.0s, 730941 effective words/s
# INFO - 2023-11-28 01:39:40,888: EPOCH 3: training on 7700 raw words (2384 effective words) took 0.0s, 372065 effective words/s
# INFO - 2023-11-28 01:39:40,899: EPOCH 4: training on 7700 raw words (2439 effective words) took 0.0s, 351372 effective words/s
# INFO - 2023-11-28 01:39:40,910: EPOCH 5: training on 7700 raw words (2385 effective words) took 0.0s, 366505 effective words/s
# INFO - 2023-11-28 01:39:40,921: EPOCH 6: training on 7700 raw words (2443 effective words) took 0.0s, 421878 effective words/s
# INFO - 2023-11-28 01:39:40,931: EPOCH 7: training on 7700 raw words (2482 effective words) took 0.0s, 425595 effective words/s
# INFO - 2023-11-28 01:39:40,942: EPOCH 8: training on 7700 raw words (2427 effective words) took 0.0s, 355906 effective words/s
# INFO - 2023-11-28 01:39:40,955: EPOCH 9: training on 7700 raw words (2373 effective words) took 0.0s, 277925 effective words/s
# INFO - 2023-11-28 01:39:40,966: EPOCH 10: training on 7700 raw words (2445 effective words) took 0.0s, 371492 effective words/s
# INFO - 2023-11-28 01:39:40,977: EPOCH 11: training on 7700 raw words (2461 effective words) took 0.0s, 373879 effective words/s
# INFO - 2023-11-28 01:39:40,988: EPOCH 12: training on 7700 raw words (2460 effective words) took 0.0s, 375515 effective words/s
# INFO - 2023-11-28 01:39:40,996: EPOCH 13: training on 7700 raw words (2420 effective words) took 0.0s, 542391 effective words/s
# INFO - 2023-11-28 01:39:41,007: EPOCH 14: training on 7700 raw words (2416 effective words) took 0.0s, 364010 effective words/s
# INFO - 2023-11-28 01:39:41,018: EPOCH 15: training on 7700 raw words (2425 effective words) took 0.0s, 392568 effective words/s
# INFO - 2023-11-28 01:39:41,027: EPOCH 16: training on 7700 raw words (2450 effective words) took 0.0s, 446075 effective words/s
# INFO - 2023-11-28 01:39:41,041: EPOCH 17: training on 7700 raw words (2448 effective words) took 0.0s, 260799 effective words/s
# INFO - 2023-11-28 01:39:41,052: EPOCH 18: training on 7700 raw words (2424 effective words) took 0.0s, 347629 effective words/s
# INFO - 2023-11-28 01:39:41,063: EPOCH 19: training on 7700 raw words (2434 effective words) took 0.0s, 405448 effective words/s
# INFO - 2023-11-28 01:39:41,074: EPOCH 20: training on 7700 raw words (2445 effective words) took 0.0s, 345588 effective words/s
# INFO - 2023-11-28 01:39:41,085: EPOCH 21: training on 7700 raw words (2430 effective words) took 0.0s, 390520 effective words/s
# INFO - 2023-11-28 01:39:41,094: EPOCH 22: training on 7700 raw words (2457 effective words) took 0.0s, 471411 effective words/s
# INFO - 2023-11-28 01:39:41,103: EPOCH 23: training on 7700 raw words (2390 effective words) took 0.0s, 542378 effective words/s
# INFO - 2023-11-28 01:39:41,111: EPOCH 24: training on 7700 raw words (2412 effective words) took 0.0s, 544776 effective words/s
# INFO - 2023-11-28 01:39:41,122: EPOCH 25: training on 7700 raw words (2459 effective words) took 0.0s, 351952 effective words/s
# INFO - 2023-11-28 01:39:41,132: EPOCH 26: training on 7700 raw words (2391 effective words) took 0.0s, 376728 effective words/s
# INFO - 2023-11-28 01:39:41,143: EPOCH 27: training on 7700 raw words (2409 effective words) took 0.0s, 414405 effective words/s
# INFO - 2023-11-28 01:39:41,153: EPOCH 28: training on 7700 raw words (2414 effective words) took 0.0s, 439388 effective words/s
# INFO - 2023-11-28 01:39:41,163: EPOCH 29: training on 7700 raw words (2450 effective words) took 0.0s, 369016 effective words/s
# INFO - 2023-11-28 01:39:41,174: EPOCH 30: training on 7700 raw words (2429 effective words) took 0.0s, 426795 effective words/s
# INFO - 2023-11-28 01:39:41,183: EPOCH 31: training on 7700 raw words (2426 effective words) took 0.0s, 496955 effective words/s
# INFO - 2023-11-28 01:39:41,192: EPOCH 32: training on 7700 raw words (2407 effective words) took 0.0s, 490669 effective words/s
# INFO - 2023-11-28 01:39:41,201: EPOCH 33: training on 7700 raw words (2464 effective words) took 0.0s, 508838 effective words/s
# INFO - 2023-11-28 01:39:41,209: EPOCH 34: training on 7700 raw words (2502 effective words) took 0.0s, 510603 effective words/s
# INFO - 2023-11-28 01:39:41,219: EPOCH 35: training on 7700 raw words (2398 effective words) took 0.0s, 502634 effective words/s
# INFO - 2023-11-28 01:39:41,228: EPOCH 36: training on 7700 raw words (2530 effective words) took 0.0s, 503357 effective words/s
# INFO - 2023-11-28 01:39:41,239: EPOCH 37: training on 7700 raw words (2437 effective words) took 0.0s, 367191 effective words/s
# INFO - 2023-11-28 01:39:41,249: EPOCH 38: training on 7700 raw words (2470 effective words) took 0.0s, 424599 effective words/s
# INFO - 2023-11-28 01:39:41,261: EPOCH 39: training on 7700 raw words (2448 effective words) took 0.0s, 384084 effective words/s
# INFO - 2023-11-28 01:39:41,270: EPOCH 40: training on 7700 raw words (2389 effective words) took 0.0s, 487075 effective words/s
# INFO - 2023-11-28 01:39:41,278: EPOCH 41: training on 7700 raw words (2385 effective words) took 0.0s, 496987 effective words/s
# INFO - 2023-11-28 01:39:41,287: EPOCH 42: training on 7700 raw words (2449 effective words) took 0.0s, 499653 effective words/s
# INFO - 2023-11-28 01:39:41,298: EPOCH 43: training on 7700 raw words (2371 effective words) took 0.0s, 376501 effective words/s
# INFO - 2023-11-28 01:39:41,308: EPOCH 44: training on 7700 raw words (2442 effective words) took 0.0s, 467939 effective words/s
# INFO - 2023-11-28 01:39:41,317: EPOCH 45: training on 7700 raw words (2422 effective words) took 0.0s, 497932 effective words/s
# INFO - 2023-11-28 01:39:41,326: EPOCH 46: training on 7700 raw words (2421 effective words) took 0.0s, 520259 effective words/s
# INFO - 2023-11-28 01:39:41,335: EPOCH 47: training on 7700 raw words (2384 effective words) took 0.0s, 448281 effective words/s
# INFO - 2023-11-28 01:39:41,346: EPOCH 48: training on 7700 raw words (2413 effective words) took 0.0s, 363941 effective words/s
# INFO - 2023-11-28 01:39:41,357: EPOCH 49: training on 7700 raw words (2383 effective words) took 0.0s, 368035 effective words/s
# INFO - 2023-11-28 01:39:41,358: Word2Vec lifecycle event {'msg': 'training on 385000 raw words (121382 effective words) took 0.5s, 239296 effective words/s', 'datetime': '2023-11-28T01:39:41.358178', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:39:41,359: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-28T01:39:41.359105', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ujjwal-shake-her/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
n2v.train(30, 0.05)
# Out:
# INFO - 2023-11-28 01:12:27,108: collecting all words and their counts
# INFO - 2023-11-28 01:12:27,109: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-28 01:12:27,110: collected 77 word types from a corpus of 2772 raw words and 924 sentences
# INFO - 2023-11-28 01:12:27,110: Creating a fresh vocabulary
# INFO - 2023-11-28 01:12:27,111: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-28T01:12:27.111332', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:12:27,111: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 2772 word corpus (100.00% of original 2772, drops 0)', 'datetime': '2023-11-28T01:12:27.111938', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:12:27,112: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-28 01:12:27,113: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-28 01:12:27,114: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 936.0878641257577 word corpus (33.8%% of prior 2772)', 'datetime': '2023-11-28T01:12:27.114003', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-28 01:12:27,115: estimated required memory for 77 words and 16 dimensions: 48356 bytes
# INFO - 2023-11-28 01:12:27,117: resetting layer weights
# INFO - 2023-11-28 01:12:27,118: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-28T01:12:27.118549', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-28 01:12:27,119: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 16 features, using sg=1 hs=0 sample=0.001 negative=10 window=3 shrink_windows=True', 'datetime': '2023-11-28T01:12:27.119024', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:12:27,160: EPOCH 0: training on 2772 raw words (902 effective words) took 0.0s, 633925 effective words/s
# INFO - 2023-11-28 01:12:27,179: EPOCH 1: training on 2772 raw words (904 effective words) took 0.0s, 568604 effective words/s
# INFO - 2023-11-28 01:12:27,236: EPOCH 2: training on 2772 raw words (930 effective words) took 0.0s, 753792 effective words/s
# INFO - 2023-11-28 01:12:27,241: EPOCH 3: training on 2772 raw words (938 effective words) took 0.0s, 634669 effective words/s
# INFO - 2023-11-28 01:12:27,245: EPOCH 4: training on 2772 raw words (912 effective words) took 0.0s, 648180 effective words/s
# INFO - 2023-11-28 01:12:27,250: EPOCH 5: training on 2772 raw words (897 effective words) took 0.0s, 669854 effective words/s
# INFO - 2023-11-28 01:12:27,256: EPOCH 6: training on 2772 raw words (941 effective words) took 0.0s, 728403 effective words/s
# INFO - 2023-11-28 01:12:27,261: EPOCH 7: training on 2772 raw words (920 effective words) took 0.0s, 722971 effective words/s
# INFO - 2023-11-28 01:12:27,266: EPOCH 8: training on 2772 raw words (939 effective words) took 0.0s, 583000 effective words/s
# INFO - 2023-11-28 01:12:27,271: EPOCH 9: training on 2772 raw words (925 effective words) took 0.0s, 854204 effective words/s
# INFO - 2023-11-28 01:12:27,275: EPOCH 10: training on 2772 raw words (947 effective words) took 0.0s, 714584 effective words/s
# INFO - 2023-11-28 01:12:27,281: EPOCH 11: training on 2772 raw words (892 effective words) took 0.0s, 832977 effective words/s
# INFO - 2023-11-28 01:12:27,286: EPOCH 12: training on 2772 raw words (926 effective words) took 0.0s, 573675 effective words/s
# INFO - 2023-11-28 01:12:27,337: EPOCH 13: training on 2772 raw words (928 effective words) took 0.0s, 584593 effective words/s
# INFO - 2023-11-28 01:12:27,361: EPOCH 14: training on 2772 raw words (958 effective words) took 0.0s, 639729 effective words/s
# INFO - 2023-11-28 01:12:27,403: EPOCH 15: training on 2772 raw words (939 effective words) took 0.0s, 596086 effective words/s
# INFO - 2023-11-28 01:12:27,408: EPOCH 16: training on 2772 raw words (928 effective words) took 0.0s, 643652 effective words/s
# INFO - 2023-11-28 01:12:27,413: EPOCH 17: training on 2772 raw words (951 effective words) took 0.0s, 672565 effective words/s
# INFO - 2023-11-28 01:12:27,606: EPOCH 18: training on 2772 raw words (946 effective words) took 0.0s, 573707 effective words/s
# INFO - 2023-11-28 01:12:27,633: EPOCH 19: training on 2772 raw words (909 effective words) took 0.0s, 39405 effective words/s
# INFO - 2023-11-28 01:12:27,679: EPOCH 20: training on 2772 raw words (916 effective words) took 0.0s, 21579 effective words/s
# INFO - 2023-11-28 01:12:27,685: EPOCH 21: training on 2772 raw words (901 effective words) took 0.0s, 513190 effective words/s
# INFO - 2023-11-28 01:12:27,690: EPOCH 22: training on 2772 raw words (936 effective words) took 0.0s, 538417 effective words/s
# INFO - 2023-11-28 01:12:27,705: EPOCH 23: training on 2772 raw words (959 effective words) took 0.0s, 715039 effective words/s
# INFO - 2023-11-28 01:12:27,771: EPOCH 24: training on 2772 raw words (959 effective words) took 0.0s, 845827 effective words/s
# INFO - 2023-11-28 01:12:27,787: EPOCH 25: training on 2772 raw words (895 effective words) took 0.0s, 672380 effective words/s
# INFO - 2023-11-28 01:12:27,792: EPOCH 26: training on 2772 raw words (912 effective words) took 0.0s, 654497 effective words/s
# INFO - 2023-11-28 01:12:27,836: EPOCH 27: training on 2772 raw words (946 effective words) took 0.0s, 562927 effective words/s
# INFO - 2023-11-28 01:12:27,881: EPOCH 28: training on 2772 raw words (949 effective words) took 0.0s, 22820 effective words/s
# INFO - 2023-11-28 01:12:27,898: EPOCH 29: training on 2772 raw words (918 effective words) took 0.0s, 588672 effective words/s
# INFO - 2023-11-28 01:12:27,899: Word2Vec lifecycle event {'msg': 'training on 83160 raw words (27823 effective words) took 0.8s, 35675 effective words/s', 'datetime': '2023-11-28T01:12:27.899372', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-28 01:12:27,899: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=16, alpha=0.05>', 'datetime': '2023-11-28T01:12:27.899948', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}

# %%
compile error
# Out:
#   Cell In[7], line 1
#     compile error
#             ^
# SyntaxError: invalid syntax

# %%
# # getting the embeddings from the model
embeddings = np.array(n2v.get_embeddings())

# %% [markdown]
# ## Showing Homophily

# %%
''' do k means clustering for different p and q values and assign 
colours to the nodes based on the cluster they belong to '''

# p = 1, q=0.5
n2v = Node2Vec(adjmat, 10, 32, 10, 80, 1, 4)
n2v.train(30, 0.05)
embeddings = np.array(n2v.get_embeddings())

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=0,n_init=10).fit(embeddings)
labels = kmeans.labels_

plot_graph(G, labels)
# Out:
# INFO - 2023-11-27 23:49:17,582: collecting all words and their counts
# INFO - 2023-11-27 23:49:17,583: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-27 23:49:17,592: collected 77 word types from a corpus of 61600 raw words and 770 sentences
# INFO - 2023-11-27 23:49:17,593: Creating a fresh vocabulary
# INFO - 2023-11-27 23:49:17,594: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-27T23:49:17.594064', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-27 23:49:17,594: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 61600 word corpus (100.00% of original 61600, drops 0)', 'datetime': '2023-11-27T23:49:17.594544', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-27 23:49:17,596: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-27 23:49:17,597: sample=0.001 downsamples 47 most-common words
# INFO - 2023-11-27 23:49:17,598: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 16653.303123646278 word corpus (27.0%% of prior 61600)', 'datetime': '2023-11-27T23:49:17.598314', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-27 23:49:17,600: estimated required memory for 77 words and 32 dimensions: 58212 bytes
# INFO - 2023-11-27 23:49:17,601: resetting layer weights
# INFO - 2023-11-27 23:49:17,602: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-27T23:49:17.602139', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-27 23:49:17,603: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 32 features, using sg=1 hs=0 sample=0.001 negative=10 window=10 shrink_windows=True', 'datetime': '2023-11-27T23:49:17.603120', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-27 23:49:17,658: EPOCH 0: training on 61600 raw words (16742 effective words) took 0.1s, 328697 effective words/s
# INFO - 2023-11-27 23:49:17,709: EPOCH 1: training on 61600 raw words (16757 effective words) took 0.0s, 367563 effective words/s
# INFO - 2023-11-27 23:49:17,750: EPOCH 2: training on 61600 raw words (16691 effective words) took 0.0s, 452007 effective words/s
# INFO - 2023-11-27 23:49:17,791: EPOCH 3: training on 61600 raw words (16707 effective words) took 0.0s, 454711 effective words/s
# INFO - 2023-11-27 23:49:17,831: EPOCH 4: training on 61600 raw words (16653 effective words) took 0.0s, 463359 effective words/s
# INFO - 2023-11-27 23:49:17,870: EPOCH 5: training on 61600 raw words (16535 effective words) took 0.0s, 467770 effective words/s
# INFO - 2023-11-27 23:49:17,908: EPOCH 6: training on 61600 raw words (16796 effective words) took 0.0s, 480860 effective words/s
# INFO - 2023-11-27 23:49:17,950: EPOCH 7: training on 61600 raw words (16675 effective words) took 0.0s, 447473 effective words/s
# INFO - 2023-11-27 23:49:17,989: EPOCH 8: training on 61600 raw words (16613 effective words) took 0.0s, 459235 effective words/s
# INFO - 2023-11-27 23:49:18,032: EPOCH 9: training on 61600 raw words (16577 effective words) took 0.0s, 432489 effective words/s
# INFO - 2023-11-27 23:49:18,075: EPOCH 10: training on 61600 raw words (16854 effective words) took 0.0s, 422328 effective words/s
# INFO - 2023-11-27 23:49:18,118: EPOCH 11: training on 61600 raw words (16569 effective words) took 0.0s, 429474 effective words/s
# INFO - 2023-11-27 23:49:18,163: EPOCH 12: training on 61600 raw words (16606 effective words) took 0.0s, 408891 effective words/s
# INFO - 2023-11-27 23:49:18,206: EPOCH 13: training on 61600 raw words (16633 effective words) took 0.0s, 427476 effective words/s
# INFO - 2023-11-27 23:49:18,248: EPOCH 14: training on 61600 raw words (16734 effective words) took 0.0s, 440687 effective words/s
# INFO - 2023-11-27 23:49:18,289: EPOCH 15: training on 61600 raw words (16443 effective words) took 0.0s, 452173 effective words/s
# INFO - 2023-11-27 23:49:18,348: EPOCH 16: training on 61600 raw words (16658 effective words) took 0.1s, 301508 effective words/s
# INFO - 2023-11-27 23:49:18,389: EPOCH 17: training on 61600 raw words (16614 effective words) took 0.0s, 450703 effective words/s
# INFO - 2023-11-27 23:49:18,429: EPOCH 18: training on 61600 raw words (16657 effective words) took 0.0s, 468136 effective words/s
# INFO - 2023-11-27 23:49:18,470: EPOCH 19: training on 61600 raw words (16761 effective words) took 0.0s, 448973 effective words/s
# INFO - 2023-11-27 23:49:18,512: EPOCH 20: training on 61600 raw words (16715 effective words) took 0.0s, 441483 effective words/s
# INFO - 2023-11-27 23:49:18,553: EPOCH 21: training on 61600 raw words (16570 effective words) took 0.0s, 449933 effective words/s
# INFO - 2023-11-27 23:49:18,598: EPOCH 22: training on 61600 raw words (16850 effective words) took 0.0s, 414104 effective words/s
# INFO - 2023-11-27 23:49:18,646: EPOCH 23: training on 61600 raw words (16771 effective words) took 0.0s, 374638 effective words/s
# INFO - 2023-11-27 23:49:18,688: EPOCH 24: training on 61600 raw words (16590 effective words) took 0.0s, 458900 effective words/s
# INFO - 2023-11-27 23:49:18,727: EPOCH 25: training on 61600 raw words (16556 effective words) took 0.0s, 466816 effective words/s
# INFO - 2023-11-27 23:49:18,764: EPOCH 26: training on 61600 raw words (16652 effective words) took 0.0s, 496015 effective words/s
# INFO - 2023-11-27 23:49:18,802: EPOCH 27: training on 61600 raw words (16614 effective words) took 0.0s, 472309 effective words/s
# INFO - 2023-11-27 23:49:18,842: EPOCH 28: training on 61600 raw words (16742 effective words) took 0.0s, 466480 effective words/s
# INFO - 2023-11-27 23:49:18,881: EPOCH 29: training on 61600 raw words (16549 effective words) took 0.0s, 475941 effective words/s
# INFO - 2023-11-27 23:49:18,882: Word2Vec lifecycle event {'msg': 'training on 1848000 raw words (499884 effective words) took 1.3s, 390902 effective words/s', 'datetime': '2023-11-27T23:49:18.882453', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-27 23:49:18,883: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=32, alpha=0.05>', 'datetime': '2023-11-27T23:49:18.883109', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}

# %% [markdown]
# ## Showing Structural Equivalence

# %%
# adjmat , window_size , embedding_size , walks_per_vertex , walk_length , p , q
n2v_SE = Node2Vec(adjmat, 3, 16, 12, 3, 1, 2)
n2v_SE.train(16, 0.05)
embeddings = np.array(n2v_SE.get_embeddings())

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=0,n_init=10).fit(embeddings)
labels = kmeans.labels_
plot_graph(G, labels)
# Out:
# INFO - 2023-11-27 23:49:19,080: collecting all words and their counts
# INFO - 2023-11-27 23:49:19,081: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 2023-11-27 23:49:19,082: collected 77 word types from a corpus of 2772 raw words and 924 sentences
# INFO - 2023-11-27 23:49:19,082: Creating a fresh vocabulary
# INFO - 2023-11-27 23:49:19,083: Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 77 unique words (100.00% of original 77, drops 0)', 'datetime': '2023-11-27T23:49:19.083506', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-27 23:49:19,084: Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 2772 word corpus (100.00% of original 2772, drops 0)', 'datetime': '2023-11-27T23:49:19.084087', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-27 23:49:19,085: deleting the raw counts dictionary of 77 items
# INFO - 2023-11-27 23:49:19,086: sample=0.001 downsamples 77 most-common words
# INFO - 2023-11-27 23:49:19,086: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 936.118778153163 word corpus (33.8%% of prior 2772)', 'datetime': '2023-11-27T23:49:19.086615', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# INFO - 2023-11-27 23:49:19,088: estimated required memory for 77 words and 16 dimensions: 48356 bytes
# INFO - 2023-11-27 23:49:19,088: resetting layer weights
# INFO - 2023-11-27 23:49:19,089: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-27T23:49:19.089538', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# INFO - 2023-11-27 23:49:19,090: Word2Vec lifecycle event {'msg': 'training model with 10 workers on 77 vocabulary and 16 features, using sg=1 hs=0 sample=0.001 negative=10 window=3 shrink_windows=True', 'datetime': '2023-11-27T23:49:19.090395', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-27 23:49:19,097: EPOCH 0: training on 2772 raw words (892 effective words) took 0.0s, 728670 effective words/s
# INFO - 2023-11-27 23:49:19,102: EPOCH 1: training on 2772 raw words (958 effective words) took 0.0s, 636507 effective words/s
# INFO - 2023-11-27 23:49:19,108: EPOCH 2: training on 2772 raw words (949 effective words) took 0.0s, 451257 effective words/s
# INFO - 2023-11-27 23:49:19,114: EPOCH 3: training on 2772 raw words (935 effective words) took 0.0s, 4340459 effective words/s
# INFO - 2023-11-27 23:49:19,119: EPOCH 4: training on 2772 raw words (1005 effective words) took 0.0s, 672679 effective words/s
# INFO - 2023-11-27 23:49:19,124: EPOCH 5: training on 2772 raw words (930 effective words) took 0.0s, 706502 effective words/s
# INFO - 2023-11-27 23:49:19,130: EPOCH 6: training on 2772 raw words (948 effective words) took 0.0s, 775016 effective words/s
# INFO - 2023-11-27 23:49:19,135: EPOCH 7: training on 2772 raw words (895 effective words) took 0.0s, 564096 effective words/s
# INFO - 2023-11-27 23:49:19,140: EPOCH 8: training on 2772 raw words (947 effective words) took 0.0s, 648442 effective words/s
# INFO - 2023-11-27 23:49:19,147: EPOCH 9: training on 2772 raw words (937 effective words) took 0.0s, 472497 effective words/s
# INFO - 2023-11-27 23:49:19,153: EPOCH 10: training on 2772 raw words (946 effective words) took 0.0s, 612253 effective words/s
# INFO - 2023-11-27 23:49:19,158: EPOCH 11: training on 2772 raw words (961 effective words) took 0.0s, 643437 effective words/s
# INFO - 2023-11-27 23:49:19,165: EPOCH 12: training on 2772 raw words (957 effective words) took 0.0s, 542355 effective words/s
# INFO - 2023-11-27 23:49:19,172: EPOCH 13: training on 2772 raw words (942 effective words) took 0.0s, 535335 effective words/s
# INFO - 2023-11-27 23:49:19,178: EPOCH 14: training on 2772 raw words (945 effective words) took 0.0s, 376642 effective words/s
# INFO - 2023-11-27 23:49:19,184: EPOCH 15: training on 2772 raw words (946 effective words) took 0.0s, 539023 effective words/s
# INFO - 2023-11-27 23:49:19,185: Word2Vec lifecycle event {'msg': 'training on 44352 raw words (15093 effective words) took 0.1s, 159563 effective words/s', 'datetime': '2023-11-27T23:49:19.185748', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# INFO - 2023-11-27 23:49:19,186: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=77, vector_size=16, alpha=0.05>', 'datetime': '2023-11-27T23:49:19.186393', 'gensim': '4.3.2', 'python': '3.8.10 (default, May 26 2023, 14:05:08) \n[GCC 9.4.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}

# %%
# Compute node degrees
node_degrees = dict(G.degree())

# Determine the maximum degree for scaling node sizes
max_degree = max(node_degrees.values())

# Define a scaling factor for node sizes
scale_factor = 200  # Adjust this as needed to control the node size

# Compute node sizes proportional to their degree
node_sizes = [scale_factor * node_degrees[node] / max_degree for node in G.nodes]

# Plot the graph with nodes sized by their degree
pos = nx.spring_layout(G)  # Use a layout algorithm that suits your needs
nx.draw(G, pos, with_labels=True, node_color=labels, cmap=plt.cm.rainbow, node_size=node_sizes)

# Add colorbar for node colors
sm = plt.cm.ScalarMappable(cmap=plt.cm.rainbow, norm=plt.Normalize(vmin=min(labels), vmax=max(labels)))
sm.set_array([])
plt.colorbar(sm, label='Cluster')
plt.show()
