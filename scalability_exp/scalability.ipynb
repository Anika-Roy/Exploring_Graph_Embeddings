# %%
import matplotlib.pyplot as plt

# %%
random_walk_sample_times = [25.47,40.46,68.35,160.8]

plt.plot([2708,3890,4777,10312], random_walk_sample_times, 'r')
plt.xlabel('Number of nodes')
plt.ylabel('Sampling Time (s)')
plt.title('Random Walk Sampling Time')
# Out:
# Text(0.5, 1.0, 'Random Walk Sampling Time')

# %%
# plt.plot([3890,10312], random_walk_total_times, 'b')
# plt.xlabel('Number of nodes')
# plt.ylabel('Sampling Time (s)')
# plt.title('Random Walk Sampling Time')
